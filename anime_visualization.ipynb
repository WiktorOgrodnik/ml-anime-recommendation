# %%
# Standard IPython notebook imports
# %matplotlib inline

import os
import json

import csv
import networkx as nx
import pyarrow
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
import math
import ast
from itertools import chain
import matplotlib.pyplot as plt
import subprocess
import sklearn.metrics
from typing import Optional
import shutil
pd.options.display.max_colwidth = 300

# %%
two_mode_data="dataset/anime-dataset-2023.csv"
users_csv="dataset/user-filtered.csv"

# %%
# %%time
# importing data from csv to pandas

class Data_factory:
    def from_csv(file: str, sep=",") -> pd.DataFrame:
        return pd.read_csv(file, sep=sep)
# Out:
# CPU times: user 25 µs, sys: 4 µs, total: 29 µs
# Wall time: 33.4 µs

# %%
users_df = Data_factory.from_csv(users_csv)

# %%
users_df.head() # is user data loaded?
len(users_df)
# Out:
# 109224747

# %%
class AnimeRecomendation:
    def __init__(self, dimensions = 32, iter = 16):
        self.users_df     = pd.DataFrame()
        self.users_count  = None
        self.dimensions   = dimensions
        self.iterations   = iter
        self.columns      = ["user", "anime"]
        self.tsv_filename = None
        
    def number_of_users(self):
        if self.users_count is None:
            self.users_count = self.users_df.max()['user_id']
        return self.users_count

    def save_to_tsv(self, tsv_filename: str):
        grouped_df        = self.grouped_df
        self.tsv_filename = tsv_filename
        columns_to_keep   = ['user_id', 'id_rating']
        grouped_df.to_csv(tsv_filename, index=False, sep='\t', columns=columns_to_keep, mode='w', header=False)

    def fit(self, users_df, lines: Optional[int] = None, rating_threshold: int = 6):
        if lines is not None:
            self.users_df = users_df.head(int(lines))
            users_df = self.users_df
        else:
            self.users_df = users_df
            
        self.users_df['id_rating'] = list(zip(self.users_df['anime_id'], self.users_df['rating']))
    
        def agg_fun(anime, rating):
            return " ".join([str(anime) for _ in range(rating - rating_threshold + 1)])

        self.grouped_df = users_df[users_df.rating >= rating_threshold]                          \
            .groupby("user_id")["id_rating"]                                                     \
            .agg(lambda animes: " ".join([agg_fun(anime, rating) for (anime,rating) in animes])) \
            .reset_index()

        return self.number_of_users()
    
    def choose(self, nousers: int):
        self.grouped_df = self.grouped_df.sample(n=nousers)
    
    def cleora_train(self, cleora_exe="cleora"):
        if self.tsv_filename is None:
            raise RuntimeError("TSV filename not yet created")
        if not os.access(cleora_exe, os.X_OK) and shutil.which(cleora_exe) is None:
            raise RuntimeError("cleora executable not found")

        command = [cleora_exe,
                   "--type", "tsv",
                   f"--columns=transient::{self.columns[0]} complex::{self.columns[1]}",
                   "--dimension", str(self.dimensions),
                   "--number-of-iterations", str(self.iterations),
                   "--prepend-field-name", "1",
                   "-f", "numpy",
                   "-o", "results",
                   "-e", "1",
                   self.tsv_filename]
        subprocess.run(command, check=True)

# %%
model = AnimeRecomendation(dimensions=128, iter=64)

# %%
# %%time

LINES = 40000000
RATING_THRESHOLD = 8

model.fit(users_df, lines=LINES, rating_threshold=RATING_THRESHOLD)
# Out:
# /tmp/ipykernel_47463/3096378535.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.users_df['id_rating'] = list(zip(self.users_df['anime_id'], self.users_df['rating']))
# CPU times: user 1min 7s, sys: 4.32 s, total: 1min 11s
# Wall time: 1min 12s
# 129988

# %%
# %%time

#model.grouped_df =  pd.read_csv("data3.tsv", sep="\t", header=None, names=["user_id", "id_rating"])
model.grouped_df
# Out:
# CPU times: user 11 µs, sys: 1 µs, total: 12 µs
# Wall time: 17.9 µs
#         user_id  \
# 0             0
# 1             1
# 2             2
# 3             3
# 4             4
#
# 114806  31173 25013 25013 30370 30370 6547 6547 9062 9062 10067 10067 35015 24833 30654 30654 21995 21995 21995 24151 24151 34636 34618 31964 31964 33486 33486 36456 36896 40465 2167 2167 4181 4181 4181 4059 4059 4059 1535 1535 28223 33988 18507 22265 26213 2890 27633 918 918 15335 15335 9969 9969 15417...
# 114807  21 31646 47 9989 28805 28805 5081 5081 12115 4901 1222 1689 1818 1575 2904 1 1 1 5 17121 1535 6746 27833 27833 23199 23199 27831 2759 3784 3784 3785 10087 11741 227 10793 21855 270 777 777 578 578 10408 10408 468 16664 16664 32491 32491 2593 572 33 33 32281 486 486 2175 1379 1379 3466 22535 9260...
# 114808  33486 30694 31646 24833 30654 30654 33506 28249 28249 31821 66 28805 28805 5081 5081 7674 7674 10030 10030 12365 12365 31043 31043 31964 110 14741 18671 4181 4181 1575 2904 2904 30127 11843 11843 1535 8086 223 22777 813 31339 28121 15 22043 10087 5114 5114 33731 30544 31737 28907 28907 31637 996...
#
# [114809 rows x 2 columns]

# %%
# %%time
# constructing the tsv data

tsv_file_name = "data2.tsv"
model.save_to_tsv(tsv_file_name)
# Out:
# CPU times: user 3.13 s, sys: 243 ms, total: 3.37 s
# Wall time: 3.61 s

# %%
# %%time

# You shouldnt be running it every time!

# Commented it out for safety reasons xd
model.cleora_train()
# Out:
# [2024-02-07T17:50:03Z INFO  cleora] Reading args...
# [src/main.rs:222] &config = Configuration {
#     produce_entity_occurrence_count: true,
#     embeddings_dimension: 128,
#     max_number_of_iteration: 64,
#     seed: None,
#     prepend_field: true,
#     log_every_n: 10000,
#     in_memory_embedding_calculation: true,
#     input: [
#         "data2.tsv",
#     ],
#     file_type: Tsv,
#     output_dir: Some(
#         "results",
#     ),
#     output_format: Numpy,
#     relation_name: "emb",
#     columns: [
#         Column {
#             name: "user",
#             transient: true,
#             complex: false,
#             reflexive: false,
#             ignored: false,
#         },
#         Column {
#             name: "anime",
#             transient: false,
#             complex: true,
#             reflexive: false,
#             ignored: false,
#         },
#     ],
# }
# [2024-02-07T17:50:03Z INFO  cleora] Starting calculation...
# [src/pipeline.rs:25] &sparse_matrices = [
#     SparseMatrix {
#         col_a_id: 0,
#         col_a_name: "user",
#         col_b_id: 1,
#         col_b_name: "anime",
#         edge_count: 0,
#         hash_2_id: {},
#         id_2_hash: [],
#         row_sum: [],
#         pair_index: {},
#         entries: [],
#     },
# ]
# [2024-02-07T17:50:03Z INFO  cleora::pipeline] Number of lines processed: 10000
# [2024-02-07T17:50:04Z INFO  cleora::pipeline] Number of lines processed: 20000
# [2024-02-07T17:50:05Z INFO  cleora::pipeline] Number of lines processed: 30000
# [2024-02-07T17:50:06Z INFO  cleora::pipeline] Number of lines processed: 40000
# [2024-02-07T17:50:06Z INFO  cleora::pipeline] Number of lines processed: 50000
# [2024-02-07T17:50:07Z INFO  cleora::pipeline] Number of lines processed: 60000
# [2024-02-07T17:50:08Z INFO  cleora::pipeline] Number of lines processed: 70000
# [2024-02-07T17:50:09Z INFO  cleora::pipeline] Number of lines processed: 80000
Dims: 128, entities: 130150, num data points: 24062056.
# [2024-02-07T17:51:42Z INFO  cleora::embedding] Done iter: 41. Dims: 128, entities: 130150, num data points: 24062056.
# [2024-02-07T17:51:44Z INFO  cleora::embedding] Done iter: 42. Dims: 128, entities: 130150, num data points: 24062056.
# [2024-02-07T17:51:46Z INFO  cleora::embedding] Done iter: 43. Dims: 128, entities: 130150, num data points: 24062056.
# [2024-02-07T17:51:48Z INFO  cleora::embedding] Done iter: 44. Dims: 128, entities: 130150, num data points: 24062056.
# [2024-02-07T17:51:51Z INFO  cleora::embedding] Done iter: 45. Dims: 128, entities: 130150, num data points: 24062056.
# [2024-02-07T17:51:53Z INFO  cleora::embedding] Done iter: 46. Dims: 128, entities: 130150, num data points: 24062056.
# [2024-02-07T17:51:55Z INFO  cleora::embedding] Done iter: 47. Dims: 128, entities: 130150, num data points: 24062056.
# [2024-02-07T17:51:57Z INFO  cleora::embedding] Done iter: 48. Dims: 128, entities: 130150, num data points: 24062056.
# [2024-02-07T17:51:59Z INFO  cleora::embedding] Done iter: 49. Dims: 128, entities: 130150, num data points: 24062056.
# [2024-02-07T17:52:02Z INFO  cleora::embedding] Done iter: 50. Dims: 128, entities: 130150, num data points: 24062056.
# [2024-02-07T17:52:04Z INFO  cleora::embedding] Done iter: 51. Dims: 128, entities: 130150, num data points: 24062056.
# [2024-02-07T17:52:06Z INFO  cleora::embedding] Done iter: 52. Dims: 128, entities: 130150, num data points: 24062056.
# [2024-02-07T17:52:08Z INFO  cleora::embedding] Done iter: 53. Dims: 128, entities: 130150, num data points: 24062056.
# [2024-02-07T17:52:11Z INFO  cleora::embedding] Done iter: 54. Dims: 128, entities: 130150, num data points: 24062056.
# [2024-02-07T17:52:13Z INFO  cleora::embedding] Done iter: 55. Dims: 128, entities: 130150, num data points: 24062056.
# [2024-02-07T17:52:15Z INFO  cleora::embedding] Done iter: 56. Dims: 128, entities: 130150, num data points: 24062056.
# [2024-02-07T17:52:17Z INFO  cleora::embedding] Done iter: 57. Dims: 128, entities: 130150, num data points: 24062056.
# [2024-02-07T17:52:20Z INFO  cleora::embedding] Done iter: 58. Dims: 128, entities: 130150, num data points: 24062056.
# [2024-02-07T17:52:22Z INFO  cleora::embedding] Done iter: 59. Dims: 128, entities: 130150, num data points: 24062056.
# [2024-02-07T17:52:24Z INFO  cleora::embedding] Done iter: 60. Dims: 128, entities: 130150, num data points: 24062056.
# [2024-02-07T17:52:26Z INFO  cleora::embedding] Done iter: 61. Dims: 128, entities: 130150, num data points: 24062056.
# [2024-02-07T17:52:28Z INFO  cleora::embedding] Done iter: 62. Dims: 128, entities: 130150, num data points: 24062056.
# CPU times: user 127 ms, sys: 23.2 ms, total: 150 ms
# Wall time: 2min 28s
# [2024-02-07T17:52:31Z INFO  cleora::embedding] Done iter: 63. Dims: 128, entities: 130150, num data points: 24062056.
# [2024-02-07T17:52:31Z INFO  cleora::embedding] Done propagating.
# [2024-02-07T17:52:31Z INFO  cleora::embedding] Start saving embeddings.
# [2024-02-07T17:52:31Z INFO  cleora::embedding] Done saving embeddings.
# [2024-02-07T17:52:31Z INFO  cleora::embedding] Finalizing embeddings calculations!
# [2024-02-07T17:52:31Z INFO  cleora] Finished in 148 sec

# %%
class RatingGenerator:
    def __init__(self):
        self.users_count  = None
        self.columns      = ["user", "anime"]
        self.rankings     = dict()

    def anime_label(idx: int) -> str:
        return f"anime__{idx}"

    def get_artifacts(self):
        d = dict()
        p = "results/emb__"
        files  = ["labels", "vects_iter"]
        suf = [".out.entities", ".out.npy"]
    
        return { f:f"{p}{self.columns[0]}__{self.columns[1]}{suf[idx]}" 
                    for idx, f in enumerate(files) }

    def load_artifacts(self):
        artifacts = self.get_artifacts()
        with open(artifacts['labels'], "r") as entities:
            self.labels     = json.load(entities)
        # Load results to numpy
        self.vects_iter     = np.load(artifacts['vects_iter'])

    def load_rankings(self, idx: int):
        real_id = self.labels.index(f"anime__{idx}")

        v = self.vects_iter[real_id]
        dist = sklearn.metrics.pairwise.cosine_similarity(v.reshape(1, -1), self.vects_iter, dense_output=True)
        ranking = (-dist).argsort()[0]

        self.rankings[self.labels[real_id]] = ranking[:15]

    def add_to_custom_ranking(self, custom_ranking, idx: int):
        anime_ranking = self.rankings[f"anime__{idx}"]

        for anime in anime_ranking:
            if anime in custom_ranking:
                custom_ranking[anime] += 1
            else:
                custom_ranking[anime] = 1

    def predict(self, already_watched):
        
        self.load_artifacts()
        custom_ranking = dict()
        
        for idx in tqdm(already_watched):
            if f"anime__{idx}" not in self.rankings:
                self.load_rankings(idx)

            self.add_to_custom_ranking(custom_ranking, idx)

        return dict(sorted(custom_ranking.items(), reverse=True, key=lambda x:x[1]))

# %%
anime_df = Data_factory.from_csv(two_mode_data)

# %%
# Ranking


ratingGenerator = RatingGenerator()

def pandas_extract_content(row, label):
    name = row[label].to_string()
    return name.split("    ")[1]

ranking = ratingGenerator.predict([67, 6702, 242])
print(ranking)
for label, times in ranking.items():
    filter = anime_df[anime_df.anime_id == label]
    if len(filter) == 0:
        continue

    print(f"{pandas_extract_content(filter, 'Name')}: {times}")
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# {7151: 1, 13083: 1, 9226: 1, 9231: 1, 9235: 1, 9236: 1, 2140: 1, 9219: 1, 5450: 1, 9237: 1, 5442: 1, 5438: 1, 2154: 1, 5432: 1, 13021: 1, 0: 1, 8430: 1, 2401: 1, 2400: 1, 2380: 1, 8458: 1, 8460: 1, 2376: 1, 8462: 1, 12032: 1, 8428: 1, 12031: 1, 12025: 1, 8500: 1, 2339: 1, 3054: 1, 5210: 1, 7296: 1, 3380: 1, 3827: 1, 8774: 1, 12110: 1, 3352: 1, 11252: 1, 8070: 1, 1646: 1, 13416: 1, 2564: 1, 1813: 1, 8829: 1}
# Fushigi na Kusuri: 1
# Aniyome: 1
# Tekkon Kinkreet: 1
# GS Mikami: 1
# Tokubetsu Jugyou 2: 1
# Mirai Nikki: 1
# Shusaku Liberty: 1
# Kingdom: 1
# Haguregumo: 1
# Youjuu Kyoushitsu Gaiden: 1
# La Seine no Hoshi: 1
# Houkago 2 The Animation: 1
# Michi (2004): 1
# Hana Dorei: 1
# Ore wa Teppei: 1
# 3-tsu no Hanashi: 1
# Tengen Toppa Gurren Lagann: Mitee Mono wa Miteen da!!: 1
# Code-E: 1
# Genshiken OVA: 1
# Shounen Ashibe (TV): 1

# %%
def extract_year(aired):
    return aired.split(",")[1].split(" ")[1]

def search_str(s, search):
    return search in str(s).lower()

def find_by_name(name):
    name = name.lower()
    mask = anime_df.apply(lambda x: x.map(lambda s: search_str(s, name)))
    return anime_df.loc[mask.any(axis=1)]

find_by_name("ghibli")
# Out:
#        anime_id                                                 Name  \
# 142         164                                        Mononoke Hime
# 176         199                        Sen to Chihiro no Kamikakushi
# 388         415                                 Tonari no Yamada-kun
# 389         416                                      Kurenai no Buta
# 404         431                                  Howl no Ugoku Shiro
# 479         512                                   Majo no Takkyuubin
# 480         513                               Tenkuu no Shiro Laputa
# 490         523                                     Tonari no Totoro
# 542         578                                       Hotaru no Haka
# 548         585                                     Mimi wo Sumaseba
# 560         597                                     Neko no Ongaeshi
# 679         743                                       Umi ga Kikoeru
# 934        1029                                      Omoide Poroporo
# 935        1030                         Heisei Tanuki Gassen Ponpoko
# 952        1047                                         On Your Mark
# 1665       1829                                            Ged Senki
# 2280       2488                                    Mei to Koneko Bus
# 2402       2616                                     Sora Iro no Tane
# 2403       2617                                             Ghiblies
# 2538       2767                               Taneyamagahara no Yoru
# 2637       2890                                  Gake no Ue no Ponyo
# 2638       2891                                         Iblard Jikan
# 2641       2895                                           Kujiratori
# 2643       2897                                             Nandarou
# 9214                                        UNKNOWN
# 9280                                        UNKNOWN
# 10770                                       UNKNOWN
# 10775                                       UNKNOWN
# 11186                          Boro the Caterpillar
# 11567                           Choju Jinbutsu Giga
# 12165                                       UNKNOWN
# 13718                                       UNKNOWN
# 16844                          Earwig and the Witch
# 23470                  Zen - Grogu and Dust Bunnies
#
#                       Other name    Score  \
# 142                        もののけ姫     8.67
# 176                     千と千尋の神隠し     8.78
# 388              ホーホケキョ となりの山田くん     7.12
# 389                          紅の豚     7.95
# 404                      ハウルの動く城     8.66
# 479                       魔女の宅急便     8.22
# 480                     天空の城ラピュタ     8.26
# 490                      となりのトトロ     8.25
# 542                        火垂るの墓     8.51
# 548                       耳をすませば     8.22
# 560                        猫の恩返し     7.72
# 679                       海がきこえる     6.54
# 934                     おもひでぽろぽろ     7.43
# 935                    平成狸合戦ぽんぽこ      7.3
# 952    On Your Mark CHAGE & ASKA     7.46
# 1665                        ゲド戦記     6.84
# 2280                    めいとこねこバス     7.28
# 2402                     そらいろのたね     5.73
# 2403                       ギブリーズ     6.36
# 2538                      種山ヶ原の夜     5.46
# 2637                     崖の上のポニョ     7.92
# 2638                     イバラード時間     6.88
# 2641                       くじらとり     6.07
# 2643                       なんだろう     5.09
# 3129                       やどさがし     6.42
# 3291                     空飛ぶ都市計画     5.94
# 3293          space station No.9     5.62
# 3294                     ポータブル空港     5.52
# 3517           金曜ロードショー オープニング映像     5.68
# 3572                     水グモもんもん     6.46
# 3763                    カゼノトオリミチ     5.94
# 4592                      星をかった日      6.9
# 4834                     コロの大さんぽ     6.42
# 5110                借りぐらしのアリエッティ     7.89
# 5311                         ピース     5.99
# 5435                      ちゅうずもう      6.5
# 5882                          旨茶     4.88
# 5896                    パン種とタマゴ姫     6.85
# 6016                     コクリコ坂から     7.79
# 6701                      たからさがし     6.09
# 7020                リトル・ニモ パイロット     6.06
# 7185                       ユキの太陽     5.35
# 7470                        風立ちぬ     8.11
# 7471                     かぐや姫の物語      8.2
# 8048                   空想の空飛ぶ機械達      6.1
# 8261                リトル・ニモ パイロット     5.86
# 8457                    思い出のマーニー     8.05
# 8626                    山賊の娘ローニャ     7.07
# 9214   ジブリがいっぱいSPECIAL ショート ショート     5.67
# 9280                        読売新聞     4.42
# 10770     太鼓の達人15周年記念ショートアニメーション     5.19
# 10775                 日清製粉グループCM     5.95
# 11186                      毛虫のボロ     6.56
# 11567                       鳥獣戯画     6.01
# 12165                  となりのおにぎり君     5.04
# 13718                 君たちはどう生きるか  UNKNOWN
# 16844                     アーヤと魔女     5.47
# 23470           禅 グローグーとマックロクロスケ     6.12
#
#                                                          Genres  \
# 142                   Action, Adventure, Award Winning, Fantasy
# 176                      Adventure, Award Winning, Supernatural
# 388                        Award Winning, Comedy, Slice of Life
# 389    Action, Adventure, Award Winning, Comedy, Drama, Romance
# 404           Adventure, Award Winning, Drama, Fantasy, Romance
# 479            Adventure, Award Winning, Comedy, Drama, Fantasy
# 480          Adventure, Award Winning, Fantasy, Romance, Sci-Fi
# 11567  Studio Ghibli animated Choujuu-Jinbutsu-Giga Emaki, the famous Japanese "Scrolls of Cartoons of Birds, Animals, and People" or "Choujuu Giga" for short, for a Marubeni Power commercial. The "Encounter" commercial promotes Plan G, a new electric power option that Marubeni Power is offering to hom...
# 12165                                                                                                                                                                                                                         The beverage company Ito En commissioned Studio Ghibli for a mascot and commercials.
# 13718  Miyazaki derived the film's title from writer Genzaburou Yoshino's 1937 masterpiece of the same name. He added that this book is a story that has great meaning to the protagonist of his film. Yoshino's book centers around a man named Koperu and his uncle, and through Koperu's spiritual growth, i...
# 16844  With large windows adorning its spick-and-span halls, St. Morwald's Home for Children serves as a warm refuge for displaced orphans. For 10-year-old Aya, she is perfectly content living without a normal family, especially since she has everyone at the orphanage wrapped around her finger. However...
# 23470                                                                                                                                                                                                         Zen: Grogu to Makkuro Kurosuke is a hand-drawn animated short by Studio Ghibli.\n\n(Source: Disney+)
#
#           Type Episodes                         Aired  ...  \
# 142      Movie      1.0                  Jul 12, 1997  ...
# 176      Movie      1.0                  Jul 20, 2001  ...
# 388      Movie      1.0                  Jul 17, 1999  ...
# 389      Movie      1.0                  Jul 18, 1992  ...
# 404      Movie      1.0                  Nov 20, 2004  ...
# 479      Movie      1.0                  Jul 29, 1989  ...
# 480      Movie      1.0                   Aug 2, 1986  ...
# 490      Movie      1.0                  Apr 16, 1988  ...
# 542      Movie      1.0                  Apr 16, 1988  ...
# 548      Movie      1.0                  Jul 15, 1995  ...
# 560      Movie      1.0                  Jul 20, 2002  ...
# 679    Special      1.0                   May 5, 1993  ...
# 934      Movie      1.0                  Jul 20, 1991  ...
# 935      Movie      1.0                  Jun 13, 1994  ...
# 952      Music      1.0                  Jun 29, 1995  ...
# 1665     Movie      1.0                  Jul 29, 2006  ...
# 2280   Special      1.0                   Oct 1, 2002  ...
# 2402   Special      3.0                  Dec 23, 1992  ...
# 2403   Special      2.0   Apr 8, 2000 to Jul 19, 2002  ...
# 2538     Movie      1.0                   Jul 7, 2006  ...
# 2637     Movie      1.0                  Jul 19, 2008  ...
# 2638       OVA      1.0                   Jul 4, 2007  ...
# 2641     Movie      1.0                   Oct 1, 2001  ...
# 2643   Special      1.0                   Nov 1, 1992  ...
# 3129   Special      1.0                   Jan 3, 2006  ...
# 3291     Music      1.0                  Sep 10, 2005  ...
# 3293     Music      1.0                   May 1, 2005  ...
# 3294     Music      1.0                  May 29, 2004  ...
# 3517     Music      1.0                  Nov 16, 2005  ...
# 3572     Movie      1.0                   Jan 3, 2006  ...
# 3763     Music      1.0                   Dec 8, 2004  ...
# 4592     Movie      1.0                   Jan 3, 2006  ...
# 4834   Special      1.0                   Oct 1, 2001  ...
# 5110     Movie      1.0                  Jul 17, 2010  ...
# 5311     Music      1.0                  Feb 25, 2009  ...
# 5435     Movie      1.0                   Jan 3, 2010  ...
# 5882   Special      2.0   Mar 5, 2001 to May 18, 2001  ...
# 5896     Movie      1.0                  Nov 20, 2010  ...
# 6016     Movie      1.0                  Jul 16, 2011  ...
# 6701     Movie      1.0                   Jun 4, 2011  ...
# 7020   Special      1.0                          1984  ...
# 3517      3058      https://cdn.myanimelist.net/images/anime/7/81238.jpg
# 3572      3625      https://cdn.myanimelist.net/images/anime/11/8110.jpg
# 3763      3676       https://cdn.myanimelist.net/images/anime/7/8980.jpg
# 4592      7669     https://cdn.myanimelist.net/images/anime/10/38233.jpg
# 4834      2995      https://cdn.myanimelist.net/images/anime/8/16252.jpg
# 5110    329316  https://cdn.myanimelist.net/images/anime/1974/116417.jpg
# 5311      2661      https://cdn.myanimelist.net/images/anime/8/81241.jpg
# 5435      2538      https://cdn.myanimelist.net/images/anime/6/23788.jpg
# 5882      2415      https://cdn.myanimelist.net/images/anime/5/27075.jpg
# 5896      5335     https://cdn.myanimelist.net/images/anime/12/27157.jpg
# 6016    190140      https://cdn.myanimelist.net/images/anime/8/32547.jpg
# 6701      1928     https://cdn.myanimelist.net/images/anime/12/34539.jpg
# 7020      1137  https://cdn.myanimelist.net/images/anime/1347/107264.jpg
# 7185      3090      https://cdn.myanimelist.net/images/anime/7/76446.jpg
# 7470    312501      https://cdn.myanimelist.net/images/anime/8/52353.jpg
# 7471    216423   https://cdn.myanimelist.net/images/anime/1935/93606.jpg
# 8048      2047     https://cdn.myanimelist.net/images/anime/10/52001.jpg
# 8261       968  https://cdn.myanimelist.net/images/anime/1218/107263.jpg
# 8457    281136      https://cdn.myanimelist.net/images/anime/7/64293.jpg
# 8626     29248     https://cdn.myanimelist.net/images/anime/11/68125.jpg
# 9214      2359      https://cdn.myanimelist.net/images/anime/4/64003.jpg
# 9280      1654      https://cdn.myanimelist.net/images/anime/8/64609.jpg
# 10770     2092     https://cdn.myanimelist.net/images/anime/10/74714.jpg
# 10775     1986     https://cdn.myanimelist.net/images/anime/11/81240.jpg
# 11186     3306   https://cdn.myanimelist.net/images/anime/1377/90940.jpg
# 11567     2523      https://cdn.myanimelist.net/images/anime/7/81247.jpg
# 12165     1380   https://cdn.myanimelist.net/images/anime/1619/93112.jpg
# 13718     8296  https://cdn.myanimelist.net/images/anime/1261/131805.jpg
# 16844    14926  https://cdn.myanimelist.net/images/anime/1242/110170.jpg
# 23470     3398  https://cdn.myanimelist.net/images/anime/1397/130985.jpg
#
# [58 rows x 24 columns]

# %%
def df_from_array(array):
    return pd.DataFrame(data=array[1:,1:], index=array[1:,0], columns=array[0,1:])

def read_data(file):
    with open(file, newline='') as csvfile:
        reader = csv.reader(csvfile, delimiter=',')
        return [ np.array([i] + list(row)) for i, row in enumerate(reader, start=-1)]

def get_genre_list(genres: str):
  return list(map(lambda x: x.strip().lower(), genres.split(",")))

def filter_out(word, col):
  return lambda row: not (word.lower() in get_genre_list(row[col]))

def filter_in(word, col):
  return lambda row: (word.lower() in get_genre_list(row[col]))

def create_two_mode_df(data):
    sub_df = data[["anime_id", "English name", "Genres"]]
    result = [['id', 'source', 'target']]
    i=0
    for _, row in sub_df.iterrows():
        for genre in get_genre_list(row['Genres']):
            to_append = [i, row['English name'], genre]
            result.append(to_append)
            i+=1
    return df_from_array(np.array(result))

def create_weighted_matrix(two_mode_df):
    assert(two_mode_df.columns.tolist() == ['source', 'target'])
    source_uniq = two_mode_df['source'].unique()
    source_len = source_uniq.shape[0]
    source_dict = {k: v for v, k in enumerate(source_uniq)}
    array = np.zeros((source_len, source_len), dtype=int)

    for _, source1 in tqdm(two_mode_df.iterrows(), total=len(two_mode_df.index)):
        for _, source2 in two_mode_df.iterrows():
            if source1['target'] == source2['target']:
                array[source_dict[source1['source']], source_dict[source2['source']]] += 1
    return pd.DataFrame(data=array, columns=source_uniq, index=source_uniq)

def create_weighted_matrix2(two_mode_df):
    adj_df = pd.crosstab(two_mode_df.source, two_mode_df.target)
    adj_np = adj_df.to_numpy()
    adj_np2 = adj_np@adj_np.T
    return (adj_np2, adj_df.index)


def create_weighted_df(matrix_df):
    result=[['', 'source', 'target', 'weight']]
    c = 0
    for rowIndex, row in tqdm(matrix_df.iterrows(), total=len(matrix_df.index)): #iterate over rows
        for colIndex, value in row.items():
            weight = matrix_df.at[rowIndex, colIndex]
            if weight > 0:
                to_append = [str(c), rowIndex, colIndex, weight]
                result.append(to_append)
                c += 1
    return df_from_array(np.array(result))

# %%
raw_data = read_data(two_mode_data)
# raw_data = raw_data[:1000]

# %%
all_data = df_from_array(np.array(raw_data))

# %%
all_data.columns
# Out:
# Index(['anime_id', 'Name', 'English name', 'Other name', 'Score', 'Genres',
#        'Synopsis', 'Type', 'Episodes', 'Aired', 'Premiered', 'Status',
#        'Producers', 'Licensors', 'Studios', 'Source', 'Duration', 'Rating',
#        'Rank', 'Popularity', 'Favorites', 'Scored By', 'Members', 'Image URL'],
#       dtype='object')

# %%
all_data = all_data[(all_data['Score'] != "UNKNOWN") & (all_data['Score'] != '')].astype({'Score': 'float'})
# all_data = all_data.drop(columns=['Synopsis', 'Aired', 'Image URL', 'Scored By', 'Members', 'Licensors'])
# all_data = all_data[all_data['Score'] > 7.0]
important_data = all_data.drop(columns=['Synopsis', 'Aired', 'Image URL', 'Scored By', 'Members', 'Licensors'])

# %%
movies = important_data[important_data['Type'] == "Movie"]
TVs = important_data[important_data['Type'] == "TV"]
specials = important_data[important_data['Type'] == "Special"]

specified = important_data

not_hentai = specified[specified.apply(filter_out("Hentai", 'Genres'), axis=1)]
hentai = specified[specified.apply(filter_in("Hentai", 'Genres'), axis=1)]

mappa = not_hentai[not_hentai.apply(filter_in("Mappa", "Studios"), axis=1)]

# %%
# not_hentai.sort_values(['Score'], ascending=False)
print(len(hentai))
print(len(not_hentai))
# Out:
# 1465
# 14227

# %%
data = all_data[["anime_id", "English name", "Genres", "Score"]]
data = data[(data['Score'] != "UNKNOWN") & (data['Score'] != '')].astype({'Score': 'float'})

# %%
data.dtypes

mapped = map(get_genre_list, data["Genres"].to_numpy().flatten().tolist())

uniq = np.unique(list(chain.from_iterable(mapped))).tolist()

print(len(uniq), uniq)
# Out:
# 22 ['action', 'adventure', 'avant garde', 'award winning', 'boys love', 'comedy', 'drama', 'ecchi', 'erotica', 'fantasy', 'girls love', 'gourmet', 'hentai', 'horror', 'mystery', 'romance', 'sci-fi', 'slice of life', 'sports', 'supernatural', 'suspense', 'unknown']

# %%
two_mode_df = create_two_mode_df(data)

two_mode_df
# Out:
#                                                   source         target
# 0                                           Cowboy Bebop         action
# 1                                           Cowboy Bebop  award winning
# 2                                           Cowboy Bebop         sci-fi
# 3                                Cowboy Bebop: The Movie         action
# 4                                Cowboy Bebop: The Movie         sci-fi
# ...                                                  ...            ...
# 30955  One Piece: Recapping Fierce Fights! The Counte...         action
# 30956  One Piece: Recapping Fierce Fights! The Counte...      adventure
# 30957  One Piece: Recapping Fierce Fights! The Counte...         comedy
# 30958  One Piece: Recapping Fierce Fights! The Counte...        fantasy
# 30959                                               Fins        unknown
#
# [30960 rows x 2 columns]

# %%
(weighted_matrix_np, weighted_matrix_index) = create_weighted_matrix2(two_mode_df)

# %%
weighted_matrix_df2 = pd.DataFrame(data=weighted_matrix_np, index=weighted_matrix_index, columns=weighted_matrix_index)

# %%
weighted_matrix_df2
# Out:
# source                                         "Deji" Meets Girl  \
# source
# "Deji" Meets Girl                                              1
# "Ippon" again!                                                 0
# "Parade" de Satie                                              0
# "Star"t                                                        0
# -OutsideR:RequieM-                                             0
# ...                                                          ...
# xxxHOLiC                                                       0
# xxxHOLiC The Movie: A Midsummer Night's Dream                  0
# ∀ Gundam                                                       0
# ∀ Gundam I: Earth Light                                        0
# ∀ Gundam II: Moonlight Butterfly                               0
#
# source                                         "Ippon" again!  \
# source
# "Deji" Meets Girl                                           0
# "Ippon" again!                                              1
# "Parade" de Satie                                           0
# "Star"t                                                     0
# -OutsideR:RequieM-                                          0
# ...                                                       ...
# xxxHOLiC                                                    0
# xxxHOLiC The Movie: A Midsummer Night's Dream               0
# ∀ Gundam                                                    0
# ∀ Gundam I: Earth Light                                     0
# ∀ Gundam II: Moonlight Butterfly                            0
#
# source                                         "Parade" de Satie  "Star"t  \
# source
# "Deji" Meets Girl                                              0        0
# "Ippon" again!                                                 0        0
# "Parade" de Satie                                              1        0
# "Star"t                                                        0        1
# -OutsideR:RequieM-                                             0        1
# ...                                                          ...      ...
# xxxHOLiC                                                       0        0
# xxxHOLiC The Movie: A Midsummer Night's Dream                  0        0
# ∀ Gundam                                                       0        0
# ∀ Gundam I: Earth Light                                        0        0
# ∀ Gundam II: Moonlight Butterfly                               0        0
#
# source                                         -OutsideR:RequieM-  .Koni-chan  \
# source
# "Deji" Meets Girl                                               0           0
# "Ippon" again!                                                  0           0
# "Parade" de Satie                                               0           0
# "Star"t                                                         1           0
# -OutsideR:RequieM-                                              1           0
# ...                                                           ...         ...
# xxxHOLiC                                                        0           1
# xxxHOLiC The Movie: A Midsummer Night's Dream                   0           1
# ∀ Gundam                                                        0           0
# ∀ Gundam I: Earth Light                                         0           0
# ∀ Gundam II: Moonlight Butterfly                                0           0
#
# source                                         .hack//G.U. Trilogy  \
# source
# "Deji" Meets Girl                                                0
# "Ippon" again!                                                   0
# "Parade" de Satie                                                0
# "Star"t                                                          0
# -OutsideR:RequieM-                                               0
# ...                                                            ...
# xxxHOLiC                                                         0
# xxxHOLiC The Movie: A Midsummer Night's Dream                    0
# ∀ Gundam                                                         1
# ∀ Gundam I: Earth Light                                          1
# ∀ Gundam II: Moonlight Butterfly                                 1
#
# source                                         .hack//G.U. Trilogy: Parody Mode  \
# source
# "Deji" Meets Girl                                                             0
# "Ippon" again!                                                                0
# "Parade" de Satie                                                             0
# "Star"t                                                                       0
# -OutsideR:RequieM-                                                            0
# ...                                                                         ...
# xxxHOLiC                                                                      1
# xxxHOLiC The Movie: A Midsummer Night's Dream                                 1
# ∀ Gundam                                                                      1
# ∀ Gundam I: Earth Light                                                       1
# ∀ Gundam II: Moonlight Butterfly                                              1
#
# source                                         .hack//Gift  \
# source
# "Deji" Meets Girl                                        0
# "Ippon" again!                                           0
# "Parade" de Satie                                        0
# "Star"t                                                  0
# -OutsideR:RequieM-                                       0
# ...                                                    ...
# xxxHOLiC                                                 1
# xxxHOLiC The Movie: A Midsummer Night's Dream            1
# ∀ Gundam                                                 0
# ∀ Gundam I: Earth Light                                  0
# ∀ Gundam II: Moonlight Butterfly                         0
#
# source                                         .hack//Legend of The Twilight  \
# source
# "Deji" Meets Girl                                                          0
# "Ippon" again!                                                             0
# "Parade" de Satie                                                          0
# "Star"t                                                                    0
# -OutsideR:RequieM-                                                         0
# ...                                                                      ...
# xxxHOLiC                                                                   1
# xxxHOLiC The Movie: A Midsummer Night's Dream                              1
# ∀ Gundam                                                                   1
# ∀ Gundam I: Earth Light                                                    0
# ∀ Gundam II: Moonlight Butterfly                                           0
#
# source                                         ...  selector spread WIXOSS  \
# source                                         ...
# "Deji" Meets Girl                              ...                       0
# "Ippon" again!                                 ...                       0
# "Parade" de Satie                              ...                       0
# "Star"t                                        ...                       1
# -OutsideR:RequieM-                             ...                       1
# ...                                            ...                     ...
# xxxHOLiC                                       ...                       0
# xxxHOLiC The Movie: A Midsummer Night's Dream  ...                       0
# ∀ Gundam                                       ...                       0
# ∀ Gundam I: Earth Light                        ...                       0
# ∀ Gundam II: Moonlight Butterfly               ...                       0
#
# source                                         sound / phantasma / mirror  \
# source
# "Deji" Meets Girl                                                       1
# "Ippon" again!                                                          0
# "Parade" de Satie                                                       0
# "Star"t                                                                 0
# -OutsideR:RequieM-                                                      0
# ...                                                                   ...
# xxxHOLiC                                                                0
# xxxHOLiC The Movie: A Midsummer Night's Dream                           0
# ∀ Gundam                                                                0
# ∀ Gundam I: Earth Light                                                 0
# ∀ Gundam II: Moonlight Butterfly                                        0
#
# source                                         teeter  the FLY BanD!  \
# source
# "Deji" Meets Girl                                   0              0
# "Ippon" again!                                      0              0
# "Parade" de Satie                                   0              0
# "Star"t                                             1              1
# -OutsideR:RequieM-                                  1              1
# ...                                               ...            ...
# xxxHOLiC                                            0              0
# xxxHOLiC The Movie: A Midsummer Night's Dream       0              0
# ∀ Gundam                                            0              0
# ∀ Gundam I: Earth Light                             0              0
# ∀ Gundam II: Moonlight Butterfly                    0              0
#
# source                                         tsuritama  xxxHOLiC  \
# source
# "Deji" Meets Girl                                      1         0
# "Ippon" again!                                         0         0
# "Parade" de Satie                                      0         0
# "Star"t                                                0         0
# -OutsideR:RequieM-                                     0         0
# ...                                                  ...       ...
# xxxHOLiC                                               1         4
# xxxHOLiC The Movie: A Midsummer Night's Dream          1         4
# ∀ Gundam                                               1         1
# ∀ Gundam I: Earth Light                                1         1
# ∀ Gundam II: Moonlight Butterfly                       1         1
#
# source                                         xxxHOLiC The Movie: A Midsummer Night's Dream  \
# source
# "Deji" Meets Girl                                                                          0
# "Ippon" again!                                                                             0
# "Parade" de Satie                                                                          0
# "Star"t                                                                                    0
# -OutsideR:RequieM-                                                                         0
# ...                                                                                      ...
# xxxHOLiC                                                                                   4
# xxxHOLiC The Movie: A Midsummer Night's Dream                                              4
# ∀ Gundam                                                                                   1
# ∀ Gundam I: Earth Light                                                                    1
# ∀ Gundam II: Moonlight Butterfly                                                           1
#
# source                                         ∀ Gundam  \
# source
# "Deji" Meets Girl                                     0
# "Ippon" again!                                        0
# "Parade" de Satie                                     0
# "Star"t                                               0
# -OutsideR:RequieM-                                    0
# ...                                                 ...
# xxxHOLiC                                              1
# xxxHOLiC The Movie: A Midsummer Night's Dream         1
# ∀ Gundam                                              6
# ∀ Gundam I: Earth Light                               3
# ∀ Gundam II: Moonlight Butterfly                      3
#
# source                                         ∀ Gundam I: Earth Light  \
# source
# "Deji" Meets Girl                                                    0
# "Ippon" again!                                                       0
# "Parade" de Satie                                                    0
# "Star"t                                                              0
# -OutsideR:RequieM-                                                   0
# ...                                                                ...
# xxxHOLiC                                                             1
# xxxHOLiC The Movie: A Midsummer Night's Dream                        1
# ∀ Gundam                                                             3
# ∀ Gundam I: Earth Light                                              3
# ∀ Gundam II: Moonlight Butterfly                                     3
#
# source                                         ∀ Gundam II: Moonlight Butterfly
# source
# "Deji" Meets Girl                                                             0
# "Ippon" again!                                                                0
# "Parade" de Satie                                                             0
# "Star"t                                                                       0
# -OutsideR:RequieM-                                                            0
# ...                                                                         ...
# xxxHOLiC                                                                      1
# xxxHOLiC The Movie: A Midsummer Night's Dream                                 1
# ∀ Gundam                                                                      3
# ∀ Gundam I: Earth Light                                                       3
# ∀ Gundam II: Moonlight Butterfly                                              3
#
# [7916 rows x 7916 columns]

# %%
weighted_matrix_df_pickle_file = "weighted_matrix_df.df"
if os.path.exists(weighted_matrix_df_pickle_file):
    weighted_matrix_df = pd.read_pickle(weighted_matrix_df_pickle_file)
else:
    weighted_matrix_df = weighted_matrix_df2
    weighted_matrix_df.to_pickle(weighted_matrix_df_pickle_file)

# %%
weighted_matrix_df
# Out:
# source                                         "Deji" Meets Girl  \
# source
# "Deji" Meets Girl                                              1
# "Ippon" again!                                                 0
# "Parade" de Satie                                              0
# "Star"t                                                        0
# -OutsideR:RequieM-                                             0
# ...                                                          ...
# xxxHOLiC                                                       0
# xxxHOLiC The Movie: A Midsummer Night's Dream                  0
# ∀ Gundam                                                       0
# ∀ Gundam I: Earth Light                                        0
# ∀ Gundam II: Moonlight Butterfly                               0
#
# source                                         "Ippon" again!  \
# source
# "Deji" Meets Girl                                           0
# "Ippon" again!                                              1
# "Parade" de Satie                                           0
# "Star"t                                                     0
# -OutsideR:RequieM-                                          0
# ...                                                       ...
# xxxHOLiC                                                    0
# xxxHOLiC The Movie: A Midsummer Night's Dream               0
# ∀ Gundam                                                    0
# ∀ Gundam I: Earth Light                                     0
# ∀ Gundam II: Moonlight Butterfly                            0
#
# source                                         "Parade" de Satie  "Star"t  \
# source
# "Deji" Meets Girl                                              0        0
# "Ippon" again!                                                 0        0
# "Parade" de Satie                                              1        0
# "Star"t                                                        0        1
# -OutsideR:RequieM-                                             0        1
# ...                                                          ...      ...
# xxxHOLiC                                                       0        0
# xxxHOLiC The Movie: A Midsummer Night's Dream                  0        0
# ∀ Gundam                                                       0        0
# ∀ Gundam I: Earth Light                                        0        0
# ∀ Gundam II: Moonlight Butterfly                               0        0
#
# source                                         -OutsideR:RequieM-  .Koni-chan  \
# source
# "Deji" Meets Girl                                               0           0
# "Ippon" again!                                                  0           0
# "Parade" de Satie                                               0           0
# "Star"t                                                         1           0
# -OutsideR:RequieM-                                              1           0
# ...                                                           ...         ...
# xxxHOLiC                                                        0           1
# xxxHOLiC The Movie: A Midsummer Night's Dream                   0           1
# ∀ Gundam                                                        0           0
# ∀ Gundam I: Earth Light                                         0           0
# ∀ Gundam II: Moonlight Butterfly                                0           0
#
# source                                         .hack//G.U. Trilogy  \
# source
# "Deji" Meets Girl                                                0
# "Ippon" again!                                                   0
# "Parade" de Satie                                                0
# "Star"t                                                          0
# -OutsideR:RequieM-                                               0
# ...                                                            ...
# xxxHOLiC                                                         0
# xxxHOLiC The Movie: A Midsummer Night's Dream                    0
# ∀ Gundam                                                         1
# ∀ Gundam I: Earth Light                                          1
# ∀ Gundam II: Moonlight Butterfly                                 1
#
# source                                         .hack//G.U. Trilogy: Parody Mode  \
# source
# "Deji" Meets Girl                                                             0
# "Ippon" again!                                                                0
# "Parade" de Satie                                                             0
# "Star"t                                                                       0
# -OutsideR:RequieM-                                                            0
# ...                                                                         ...
# xxxHOLiC                                                                      1
# xxxHOLiC The Movie: A Midsummer Night's Dream                                 1
# ∀ Gundam                                                                      1
# ∀ Gundam I: Earth Light                                                       1
# ∀ Gundam II: Moonlight Butterfly                                              1
#
# source                                         .hack//Gift  \
# source
# "Deji" Meets Girl                                        0
# "Ippon" again!                                           0
# "Parade" de Satie                                        0
# "Star"t                                                  0
# -OutsideR:RequieM-                                       0
# ...                                                    ...
# xxxHOLiC                                                 1
# xxxHOLiC The Movie: A Midsummer Night's Dream            1
# ∀ Gundam                                                 0
# ∀ Gundam I: Earth Light                                  0
# ∀ Gundam II: Moonlight Butterfly                         0
#
# source                                         .hack//Legend of The Twilight  \
# source
# "Deji" Meets Girl                                                          0
# "Ippon" again!                                                             0
# "Parade" de Satie                                                          0
# "Star"t                                                                    0
# -OutsideR:RequieM-                                                         0
# ...                                                                      ...
# xxxHOLiC                                                                   1
# xxxHOLiC The Movie: A Midsummer Night's Dream                              1
# ∀ Gundam                                                                   1
# ∀ Gundam I: Earth Light                                                    0
# ∀ Gundam II: Moonlight Butterfly                                           0
#
# source                                         ...  selector spread WIXOSS  \
# source                                         ...
# "Deji" Meets Girl                              ...                       0
# "Ippon" again!                                 ...                       0
# "Parade" de Satie                              ...                       0
# "Star"t                                        ...                       1
# -OutsideR:RequieM-                             ...                       1
# ...                                            ...                     ...
# xxxHOLiC                                       ...                       0
# xxxHOLiC The Movie: A Midsummer Night's Dream  ...                       0
# ∀ Gundam                                       ...                       0
# ∀ Gundam I: Earth Light                        ...                       0
# ∀ Gundam II: Moonlight Butterfly               ...                       0
#
# source                                         sound / phantasma / mirror  \
# source
# "Deji" Meets Girl                                                       1
# "Ippon" again!                                                          0
# "Parade" de Satie                                                       0
# "Star"t                                                                 0
# -OutsideR:RequieM-                                                      0
# ...                                                                   ...
# xxxHOLiC                                                                0
# xxxHOLiC The Movie: A Midsummer Night's Dream                           0
# ∀ Gundam                                                                0
# ∀ Gundam I: Earth Light                                                 0
# ∀ Gundam II: Moonlight Butterfly                                        0
#
# source                                         teeter  the FLY BanD!  \
# source
# "Deji" Meets Girl                                   0              0
# "Ippon" again!                                      0              0
# "Parade" de Satie                                   0              0
# "Star"t                                             1              1
# -OutsideR:RequieM-                                  1              1
# ...                                               ...            ...
# xxxHOLiC                                            0              0
# xxxHOLiC The Movie: A Midsummer Night's Dream       0              0
# ∀ Gundam                                            0              0
# ∀ Gundam I: Earth Light                             0              0
# ∀ Gundam II: Moonlight Butterfly                    0              0
#
# source                                         tsuritama  xxxHOLiC  \
# source
# "Deji" Meets Girl                                      1         0
# "Ippon" again!                                         0         0
# "Parade" de Satie                                      0         0
# "Star"t                                                0         0
# -OutsideR:RequieM-                                     0         0
# ...                                                  ...       ...
# xxxHOLiC                                               1         4
# xxxHOLiC The Movie: A Midsummer Night's Dream          1         4
# ∀ Gundam                                               1         1
# ∀ Gundam I: Earth Light                                1         1
# ∀ Gundam II: Moonlight Butterfly                       1         1
#
# source                                         xxxHOLiC The Movie: A Midsummer Night's Dream  \
# source
# "Deji" Meets Girl                                                                          0
# "Ippon" again!                                                                             0
# "Parade" de Satie                                                                          0
# "Star"t                                                                                    0
# -OutsideR:RequieM-                                                                         0
# ...                                                                                      ...
# xxxHOLiC                                                                                   4
# xxxHOLiC The Movie: A Midsummer Night's Dream                                              4
# ∀ Gundam                                                                                   1
# ∀ Gundam I: Earth Light                                                                    1
# ∀ Gundam II: Moonlight Butterfly                                                           1
#
# source                                         ∀ Gundam  \
# source
# "Deji" Meets Girl                                     0
# "Ippon" again!                                        0
# "Parade" de Satie                                     0
# "Star"t                                               0
# -OutsideR:RequieM-                                    0
# ...                                                 ...
# xxxHOLiC                                              1
# xxxHOLiC The Movie: A Midsummer Night's Dream         1
# ∀ Gundam                                              6
# ∀ Gundam I: Earth Light                               3
# ∀ Gundam II: Moonlight Butterfly                      3
#
# source                                         ∀ Gundam I: Earth Light  \
# source
# "Deji" Meets Girl                                                    0
# "Ippon" again!                                                       0
# "Parade" de Satie                                                    0
# "Star"t                                                              0
# -OutsideR:RequieM-                                                   0
# ...                                                                ...
# xxxHOLiC                                                             1
# xxxHOLiC The Movie: A Midsummer Night's Dream                        1
# ∀ Gundam                                                             3
# ∀ Gundam I: Earth Light                                              3
# ∀ Gundam II: Moonlight Butterfly                                     3
#
# source                                         ∀ Gundam II: Moonlight Butterfly
# source
# "Deji" Meets Girl                                                             0
# "Ippon" again!                                                                0
# "Parade" de Satie                                                             0
# "Star"t                                                                       0
# -OutsideR:RequieM-                                                            0
# ...                                                                         ...
# xxxHOLiC                                                                      1
# xxxHOLiC The Movie: A Midsummer Night's Dream                                 1
# ∀ Gundam                                                                      3
# ∀ Gundam I: Earth Light                                                       3
# ∀ Gundam II: Moonlight Butterfly                                              3
#
# [7916 rows x 7916 columns]

# %%
# weighted_df_pickle_file = "weighted_df.df"
# if os.path.exists(weighted_df_pickle_file):
#     weighted_df = pd.read_pickle(weighted_df_pickle_file)
# else:
#     weighted_df = create_weighted_df(weighted_matrix_df)
#     weighted_df.to_pickle(weighted_df_pickle_file)

# %%
# weighted_df

# %%
# weighted_df.columns

# %%
# for i in [3, 2, 1]:
# G = nx.from_pandas_edgelist(
#         weighted_df, source='source',
#         target='target', edge_attr='weight')

plt.figure(figsize=(35,35))

G = nx.from_numpy_array(weighted_matrix_np)
graph_pos = nx.spring_layout(G)
nx.draw_networkx_nodes(G, graph_pos, node_size=10, node_color='blue', alpha=0.3)
nx.draw_networkx_edges(G, graph_pos)
nx.draw_networkx_labels(G, graph_pos, font_size=8, font_family='sans-serif')

# plt.show()

# nx.draw(G)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 11
#       9 graph_pos = nx.spring_layout(G)
#      10 nx.draw_networkx_nodes(G, graph_pos, node_size=10, node_color='blue', alpha=0.3)
# ---> 11 nx.draw_networkx_edges(G, graph_pos)
#      12 nx.draw_networkx_labels(G, graph_pos, font_size=8, font_family='sans-serif')
#      14 # plt.show()
#      15
#      16 # nx.draw(G)
#
# File ~/.pyenv/versions/3.11.6/envs/ml-anime/lib/python3.11/site-packages/networkx/drawing/nx_pylab.py:902, in draw_networkx_edges(G, pos, edgelist, width, edge_color, style, alpha, arrowstyle, arrowsize, edge_cmap, edge_vmin, edge_vmax, ax, arrows, label, node_size, nodelist, node_shape, connectionstyle, min_source_margin, min_target_margin)
#     900 edge_viz_obj = _draw_networkx_edges_line_collection()
#     901 # Make sure selfloop edges are also drawn
# --> 902 selfloops_to_draw = [loop for loop in nx.selfloop_edges(G) if loop in edgelist]
#     903 if selfloops_to_draw:
#     904     fancy_edges_indices = [
#     905         edgelist_tuple.index(loop) for loop in selfloops_to_draw
#     906     ]
#
# File ~/.pyenv/versions/3.11.6/envs/ml-anime/lib/python3.11/site-packages/networkx/drawing/nx_pylab.py:902, in <listcomp>(.0)
#     900 edge_viz_obj = _draw_networkx_edges_line_collection()
#     901 # Make sure selfloop edges are also drawn
# --> 902 selfloops_to_draw = [loop for loop in nx.selfloop_edges(G) if loop in edgelist]
#     903 if selfloops_to_draw:
#     904     fancy_edges_indices = [
#     905         edgelist_tuple.index(loop) for loop in selfloops_to_draw
#     906     ]
#
# KeyboardInterrupt:

# %%
plt.savefig("plot.svg", dpi=1200)

# %%
net = Network(notebook=True)
net.from_nx(G)
net.show("example.html")
