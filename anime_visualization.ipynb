# %%
# Standard IPython notebook imports
# %matplotlib inline

import os
import json

import csv
import networkx as nx
import pyarrow
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
import math
import ast
from itertools import chain
import matplotlib.pyplot as plt
import subprocess
import sklearn.metrics
from typing import Optional
import shutil
pd.options.display.max_colwidth = 300

# %%
two_mode_data="dataset/anime-dataset-2023.csv"
users_csv="dataset/user-filtered.csv"

# %%
# %%time
# importing data from csv to pandas

class Data_factory:
    def from_csv(file: str) -> pd.DataFrame:
        return pd.read_csv(file)

anime_df = Data_factory.from_csv(two_mode_data)
users_df = Data_factory.from_csv(users_csv)
# Out:
# CPU times: user 33.8 s, sys: 30.7 s, total: 1min 4s
# Wall time: 2min 34s

# %%
users_df.head() # is user data loaded?
len(users_df)
# Out:
# 109224747

# %%
class AnimeRecomendation:
    def __init__(self, dimensions = 32, iter = 16):
        self.users_df     = pd.DataFrame()
        self.users_count  = None
        self.dimensions   = dimensions
        self.iterations   = iter
        self.columns      = ["user", "anime"]
        self.tsv_filename = None
        self.rankings     = dict()

    def anime_label(idx: int) -> str:
        return f"anime__{idx}"

    def number_of_users(self):
        if self.users_count is None:
            self.users_count = self.users_df.max()['user_id']
        return self.users_count

    def save_to_tsv(self, tsv_filename: str):
        grouped_df        = self.grouped_df
        users_count       = self.number_of_users()
        self.tsv_filename = tsv_filename
        columns_to_keep   = ['user_id', 'id_rating']
        grouped_df.to_csv(tsv_filename, index=False, sep='\t', columns=columns_to_keep, mode='w', header=False)

    def fit(self, users_df, lines: Optional[int] = None, rating_threshold: int = 6):
        if lines is not None:
            self.users_df = users_df.head(int(lines))
            users_df = self.users_df
        else:
            self.users_df = users_df
            
        self.users_df['id_rating'] = list(zip(self.users_df['anime_id'], self.users_df['rating']))
    
        def agg_fun(anime, rating):
            return " ".join([str(anime) for _ in range(rating - rating_threshold + 1)])

        self.grouped_df = users_df[users_df.rating >= rating_threshold]                          \
            .groupby("user_id")["id_rating"]                                                     \
            .agg(lambda animes: " ".join([agg_fun(anime, rating) for (anime,rating) in animes])) \
            .reset_index()

            
#         self.grouped_df = self.grouped_df \
#             .filter(items=['user_id', 'id_rating'])  \
#             .apply(list, axis=1)                                           \
#             .agg(lambda animes: " ".join([str(anime) for anime in animes])) \

#         self.number_of_users()
        return self.grouped_df

    def get_artifacts(self, name: str):
        d = dict()
        p = "results/emb__"
        files  = ["labels", "vects_iter"]
        suf = [".out.entities", ".out.npy"]
    
        return { f:f"{p}{name}__{name}{suf[idx]}" 
                    for idx, f in enumerate(files) }

    def cleora_train(self, cleora_exe="cleora"):
        if self.tsv_filename is None:
            raise RuntimeError("TSV filename not yet created")
        if not os.access(cleora_exe, os.X_OK) and shutil.which(cleora_exe) is None:
            raise RuntimeError("cleora executable not found")

        command = [cleora_exe,
                   "--type", "tsv",
                   f"--columns={self.columns[0]} complex::reflexive::{self.columns[1]}",
                   "--dimension", str(self.dimensions),
                   "--number-of-iterations", str(self.iterations),
                   "--prepend-field-name", "1",
                   "-f", "numpy",
                   "-o", "results",
                   "-e", "0",
                   self.tsv_filename]
        subprocess.run(command, check=True, stderr=subprocess.DEVNULL)

    def load_artifacts(self):
        artifacts = self.get_artifacts(self.columns[1])
        with open(artifacts['labels'], "r") as entities:
            self.labels     = json.load(entities)
        # Load results to numpy
        self.vects_iter     = np.load(artifacts['vects_iter'])

    def load_rankings(self, idx: int):
        real_id = self.labels.index(f"anime__{idx}")

        v = self.vects_iter[real_id]
        dist = sklearn.metrics.pairwise.cosine_similarity(v.reshape(1, -1), self.vects_iter, dense_output=True)
        ranking = (-dist).argsort()[0]

        self.rankings[self.labels[real_id]] = ranking[:15]

    def add_to_custom_ranking(self, custom_ranking, idx: int):
        anime_ranking = self.rankings[f"anime__{idx}"]

        for anime in anime_ranking:
            if anime in custom_ranking:
                custom_ranking[anime] += 1
            else:
                custom_ranking[anime] = 1

    def predict(self, already_watched):
        
        self.load_artifacts()
        custom_ranking = dict()
        
        for idx in tqdm(already_watched):
            if f"anime__{idx}" not in self.rankings:
                self.load_rankings(idx)

            self.add_to_custom_ranking(custom_ranking, idx)

        return dict(sorted(custom_ranking.items(), reverse=True, key=lambda x:x[1]))

# %%
# %%time

LINES = 2000000
RATING_THRESHOLD = 6

model = AnimeRecomendation()
model.fit(users_df, lines=LINES, rating_threshold=RATING_THRESHOLD)
# Out:
# /tmp/ipykernel_104018/1477554926.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.users_df['id_rating'] = list(zip(self.users_df['anime_id'], self.users_df['rating']))
# CPU times: user 3.37 s, sys: 305 ms, total: 3.68 s
# Wall time: 4.26 s
#       user_id  \
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4
# ...       ...
# 6003     6806
# 6004     6807
# 6005     6808
# 6006     6809
# 6007     6810
#
#                                                                                                                                                                                                                                                                                                         id_rating
# 0     67 67 67 67 6702 6702 242 242 242 242 242 21 21 21 21 21 24 24 24 24 4722 4722 4722 6098 3125 3125 3125 3125 481 481 481 481 481 68 1689 2913 1250 1250 356 356 356 356 121 121 121 121 430 430 430 430 1829 1829 1571 1571 1571 1571 1571 578 578 578 578 578 431 431 431 2762 2762 2762 2762 570 570 3...
# 1     37403 37403 37403 7674 7674 34566 34566 40852 40852 40852 40852 10087 10087 40052 40052 40052 40748 40748 40748 40748 21 21 21 21 26243 26243 42203 42203 42203 42203 40028 40028 40028 40028 40028 3972 3972 481 481 481 22199 22199 6547 9919 9919 9919 5081 5081 5081 31043 31043 31043 31043 31964 3...
# 2     235 235 235 235 235 5042 5042 5042 7593 7593 7593 21 21 21 21 22 22 22 22 5762 5762 31580 31580 35028 35028 35028 368 368 368 31964 31964 31964 33486 33486 33486 33486 31740 31740 1575 1575 1575 1575 2904 2904 2904 2904 2904 1535 1535 1535 1535 1535 28223 28223 28223 226 226 226 38671 38671 3867...
# 3     6114 6114 6114 199 199 199 199 849 849 849 33352 33352 33352 33352 33352 31646 31646 31646 31646 32998 32998 32998 25397 12291 12291 1292 1292 1292 34881 34881 34881 32323 32323 22199 22199 4744 4744 47 47 47 47 22729 22729 32828 32828 32828 22147 22147 22147 6547 6547 6547 9989 9989 9989 11433 ...
# constructing the tsv data

tsv_file_name = "data3.tsv"
model.save_to_tsv(tsv_file_name)
# Out:
# CPU times: user 927 ms, sys: 25.8 ms, total: 953 ms
# Wall time: 1.03 s

# %%
# %%time
# # alternative

# lines_n = 1000000
# tsv_file_name_n = "data2.tsv"
# grouped_df_n =                             \
#     users_df[users_df.rating >= 6]         \
#     .head(lines_n)                         \
#     .filter(items=["user_id", "anime_id"]) \
#     .to_csv(tsv_file_name_n, index=False, sep="\t")

# %%
# %%time

# You shouldnt be running it every time!

# Commented it out for safety reasons xd
model.cleora_train(cleora_exe="../cleora/target/release/cleora")

# %%
# Ranking

def pandas_extract_content(row, label):
    name = row[label].to_string()
    return name.split("    ")[1]

ranking = model.predict([67, 6702, 242])
print(ranking)
for label, times in ranking.items():
    filter = anime_df[anime_df.anime_id == label]
    if len(filter) == 0:
        continue

    print(f"{pandas_extract_content(filter, "Name")}: {times}")
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# {15: 2, 0: 1, 4922: 1, 5176: 1, 2723: 1, 1763: 1, 3077: 1, 2683: 1, 1482: 1, 5745: 1, 960: 1, 3856: 1, 6331: 1, 3582: 1, 1037: 1, 1: 1, 106: 1, 990: 1, 4698: 1, 4534: 1, 4532: 1, 1076: 1, 3171: 1, 10364: 1, 1201: 1, 1093: 1, 3221: 1, 44: 1, 2800: 1, 3071: 1, 2: 1, 1039: 1, 3200: 1, 1928: 1, 3105: 1, 2627: 1, 1787: 1, 3563: 1, 5635: 1, 5955: 1, 5707: 1, 4251: 1, 765: 1, 685: 1}
# Eyeshield 21: 2
# D4 Princess: 1
# Midnight Panther: 1
# Warau Salesman: 1
# Tokyo Majin Gakuen Kenpucho: Tou Dai Ni Maku: 1
# D.Gray-man: 1
# Shin Chou Kyou Ryo: Condor Hero II: 1
# Ten Little Gall Force: 1
# Mashou no Kao: 1
# Saint Beast: Seijuu Kourin-hen: 1
# Cowboy Bebop: 1
# Hana yori Dango: 1
# Kamisama Kazoku: 1
# Jokei Kazoku: Inbou: 1
# Choujin Locke: Shinsekai Sentai: 1
# Taiyou no Yuusha Fighbird: 1
# Wizardry: 1
# Ryoujoku Hitozuma Onsen: 1
# Oishinbo: 1
# Shakugan no Shana-tan Movie: 1
# Rurouni Kenshin: Meiji Kenkaku Romantan - Tsuioku-hen: 1
# Candy Candy: 1
# Uchuu Senkan Yamato: Aratanaru Tabidachi: 1
# Mizuiro (2003): 1
# Early Reins: 1
# Chikansha Thomas: 1
# Viper GTS: 1
# Momone: 1
# Toaru Majutsu no Index-tan: 1
# Chou Henshin Cosprayers Specials: 1
# To Heart: Remember My Memories: 1

# %%
def extract_year(aired):
    return aired.split(",")[1].split(" ")[1]

def search_str(s, search):
    return search in str(s).lower()

mask = anime_df.apply(lambda x: x.map(lambda s: search_str(s, "naruto")))

anime_df.loc[mask.any(axis=1)]
# Out:
#        anime_id  \
# 10           20
# 414         442
# 557         594
# 696         761
# 848         936
# 975        1074
# 1574       1735
# 1963       2144
# 2058       2248
# 2267       2472
# 2599       2832
# 3506       4134
# 3629       4437
# 4542       6325
# 4971       7367
# 5289       8246
# 5585       8993
# 7001                     ROAD TO NINJA NARUTO THE MOVIE     7.68
# 7528                          THE LAST NARUTO THE MOVIE     7.79
# 7740                                          四百二十連敗ガール     5.68
# 8066                         ナルト-NARUTO-疾風伝 サニー・サイド・バトル     7.56
# 8762                                              にゃ〜めん     5.49
# 9830                          BORUTO -NARUTO THE MOVIE-      7.4
# 11288             BORUTO -NARUTO THE MOVIE- ナルトが火影になった日     7.33
# 12427                  BORUTO -NARUTO NEXT GENERATIONS-     6.06
# 13621      「紙兎ロぺ」×「BORUTO-ボルト- NARUTO NEXT　GENERATIONS」     5.48
# 15640                                    D4DJ First Mix     7.64
# 16363                                           Newsong     6.34
# 23318                                    ROAD OF NARUTO     8.49
# 24174            BORUTO -NARUTO NEXT GENERATIONS- (第二部)  UNKNOWN
# 24175                                          ナルト新作アニメ  UNKNOWN
# 24677                                               ナルト  UNKNOWN
#
#                                                                        Genres  \
# 10                                                 Action, Adventure, Fantasy
# 414                                                Action, Adventure, Fantasy
# 557                                                Action, Adventure, Fantasy
# 696                                                         Adventure, Comedy
# 848                                                Action, Adventure, Fantasy
# 975                                                                    Action
# 1574                                               Action, Adventure, Fantasy
# 1963                                               Action, Adventure, Fantasy
# 2058                                                  Action, Comedy, Fantasy
# 2267                                               Action, Adventure, Fantasy
# 2599   Adventure, Comedy, Drama, Fantasy, Sci-Fi, Slice of Life, Supernatural
# 3506                                                                   Action
# 3629                                               Action, Adventure, Fantasy
# 4542                                               Action, Adventure, Fantasy
# 4971                                                          Action, Fantasy
# 5289                                               Action, Adventure, Fantasy
# 5585                                              Comedy, Supernatural, Ecchi
# 6038                                                          Action, Fantasy
# 6267                                               Action, Adventure, Fantasy
# 6291                                                           Action, Comedy
# 6301                                                        Action, Adventure
# 6856                                                           Action, Comedy
# 7001                                               Action, Adventure, Fantasy
# 7528                                      Action, Adventure, Fantasy, Romance
# 7740                                                          Comedy, Romance
# 8066                                                 Comedy, Fantasy, Gourmet
# 8762                                                                   Comedy
# 9830                                               Action, Adventure, Fantasy
# 11288                                              Action, Adventure, Fantasy
# 12427                                              Action, Adventure, Fantasy
# 13621                                                                  Comedy
# 15640                                                                 UNKNOWN
# 16363                                                                  Sci-Fi
# 23318                                                         Action, Fantasy
# 24174                                              Action, Adventure, Fantasy
# 24175                                              Action, Adventure, Fantasy
# 24677                                      Action, Adventure, Comedy, Fantasy
#
#                                                                                                                                                                                                                                                                                                           Synopsis  \
# 10     Moments prior to Naruto Uzumaki's birth, a huge demon known as the Kyuubi, the Nine-Tailed Fox, attacked Konohagakure, the Hidden Leaf Village, and wreaked havoc. In order to put an end to the Kyuubi's rampage, the leader of the village, the Fourth Hokage, sacrificed his life and sealed the mons...
# 414    Naruto Uzumaki and his squadmates, Sasuke Uchiha and Sakura Haruno, are sent on a mission to escort a movie crew on its way to film in the Land of Snow. They soon find out that they are accompanying a famous actress, Yukie Fujikaze, who persistently refuses to travel there, making the trip far m...
# 1963   https://cdn.myanimelist.net/images/anime/1918/134487.jpg
# 2058        https://cdn.myanimelist.net/images/anime/1/2473.jpg
# 2267   https://cdn.myanimelist.net/images/anime/1703/134493.jpg
# 2599      https://cdn.myanimelist.net/images/anime/13/62923.jpg
# 3506       https://cdn.myanimelist.net/images/anime/5/51895.jpg
# 3629   https://cdn.myanimelist.net/images/anime/1484/134494.jpg
# 4542   https://cdn.myanimelist.net/images/anime/1493/116732.jpg
# 4971      https://cdn.myanimelist.net/images/anime/11/27050.jpg
# 5289   https://cdn.myanimelist.net/images/anime/1479/116734.jpg
# 5585   https://cdn.myanimelist.net/images/anime/1322/111777.jpg
# 6038       https://cdn.myanimelist.net/images/anime/3/30485.jpg
# 6267   https://cdn.myanimelist.net/images/anime/1500/134496.jpg
# 6291      https://cdn.myanimelist.net/images/anime/10/31573.jpg
# 6301       https://cdn.myanimelist.net/images/anime/9/30813.jpg
# 6856      https://cdn.myanimelist.net/images/anime/13/36475.jpg
# 7001    https://cdn.myanimelist.net/images/anime/1620/94336.jpg
# 7528   https://cdn.myanimelist.net/images/anime/1491/134498.jpg
# 7740      https://cdn.myanimelist.net/images/anime/10/47723.jpg
# 8066    https://cdn.myanimelist.net/images/anime/1047/91638.jpg
# 8762       https://cdn.myanimelist.net/images/anime/2/59331.jpg
# 9830       https://cdn.myanimelist.net/images/anime/4/78280.jpg
# 11288      https://cdn.myanimelist.net/images/anime/6/77678.jpg
# 12427   https://cdn.myanimelist.net/images/anime/1091/99847.jpg
# 13621      https://cdn.myanimelist.net/images/anime/3/88377.jpg
# 15640  https://cdn.myanimelist.net/images/anime/1765/109713.jpg
# 16363  https://cdn.myanimelist.net/images/anime/1604/105144.jpg
# 23318  https://cdn.myanimelist.net/images/anime/1731/128787.jpg
# 24174  https://cdn.myanimelist.net/images/anime/1604/134068.jpg
# 24175  https://cdn.myanimelist.net/images/anime/1378/137310.jpg
# 24677  https://cdn.myanimelist.net/images/anime/1587/136098.jpg
#
# [37 rows x 24 columns]

# %%
def df_from_array(array):
    return pd.DataFrame(data=array[1:,1:], index=array[1:,0], columns=array[0,1:])

def read_data(file):
    with open(file, newline='') as csvfile:
        reader = csv.reader(csvfile, delimiter=',')
        return [ np.array([i] + list(row)) for i, row in enumerate(reader, start=-1)]

def get_genre_list(genres: str):
  return list(map(lambda x: x.strip().lower(), genres.split(",")))

def filter_out(word, col):
  return lambda row: not (word.lower() in get_genre_list(row[col]))

def filter_in(word, col):
  return lambda row: (word.lower() in get_genre_list(row[col]))

def create_two_mode_df(data):
    sub_df = data[["anime_id", "English name", "Genres"]]
    result = [['id', 'source', 'target']]
    i=0
    for _, row in sub_df.iterrows():
        for genre in get_genre_list(row['Genres']):
            to_append = [i, row['English name'], genre]
            result.append(to_append)
            i+=1
    return df_from_array(np.array(result))

def create_weighted_matrix(two_mode_df):
    assert(two_mode_df.columns.tolist() == ['source', 'target'])
    source_uniq = two_mode_df['source'].unique()
    source_len = source_uniq.shape[0]
    source_dict = {k: v for v, k in enumerate(source_uniq)}
    array = np.zeros((source_len, source_len), dtype=int)

    for _, source1 in tqdm(two_mode_df.iterrows(), total=len(two_mode_df.index)):
        for _, source2 in two_mode_df.iterrows():
            if source1['target'] == source2['target']:
                array[source_dict[source1['source']], source_dict[source2['source']]] += 1
    return pd.DataFrame(data=array, columns=source_uniq, index=source_uniq)

def create_weighted_matrix2(two_mode_df):
    adj_df = pd.crosstab(two_mode_df.source, two_mode_df.target)
    adj_np = adj_df.to_numpy()
    adj_np2 = adj_np@adj_np.T
    return (adj_np2, adj_df.index)


def create_weighted_df(matrix_df):
    result=[['', 'source', 'target', 'weight']]
    c = 0
    for rowIndex, row in tqdm(matrix_df.iterrows(), total=len(matrix_df.index)): #iterate over rows
        for colIndex, value in row.items():
            weight = matrix_df.at[rowIndex, colIndex]
            if weight > 0:
                to_append = [str(c), rowIndex, colIndex, weight]
                result.append(to_append)
                c += 1
    return df_from_array(np.array(result))

# %%
raw_data = read_data(two_mode_data)
# raw_data = raw_data[:1000]

# %%
all_data = df_from_array(np.array(raw_data))

# %%
all_data.columns
# Out:
# Index(['anime_id', 'Name', 'English name', 'Other name', 'Score', 'Genres',
#        'Synopsis', 'Type', 'Episodes', 'Aired', 'Premiered', 'Status',
#        'Producers', 'Licensors', 'Studios', 'Source', 'Duration', 'Rating',
#        'Rank', 'Popularity', 'Favorites', 'Scored By', 'Members', 'Image URL'],
#       dtype='object')

# %%
all_data = all_data[(all_data['Score'] != "UNKNOWN") & (all_data['Score'] != '')].astype({'Score': 'float'})
# all_data = all_data.drop(columns=['Synopsis', 'Aired', 'Image URL', 'Scored By', 'Members', 'Licensors'])
# all_data = all_data[all_data['Score'] > 7.0]
important_data = all_data.drop(columns=['Synopsis', 'Aired', 'Image URL', 'Scored By', 'Members', 'Licensors'])

# %%
movies = important_data[important_data['Type'] == "Movie"]
TVs = important_data[important_data['Type'] == "TV"]
specials = important_data[important_data['Type'] == "Special"]

specified = important_data

not_hentai = specified[specified.apply(filter_out("Hentai", 'Genres'), axis=1)]
hentai = specified[specified.apply(filter_in("Hentai", 'Genres'), axis=1)]

mappa = not_hentai[not_hentai.apply(filter_in("Mappa", "Studios"), axis=1)]

# %%
# not_hentai.sort_values(['Score'], ascending=False)
print(len(hentai))
print(len(not_hentai))
# Out:
# 1465
# 14227

# %%
data = all_data[["anime_id", "English name", "Genres", "Score"]]
data = data[(data['Score'] != "UNKNOWN") & (data['Score'] != '')].astype({'Score': 'float'})

# %%
data.dtypes

mapped = map(get_genre_list, data["Genres"].to_numpy().flatten().tolist())

uniq = np.unique(list(chain.from_iterable(mapped))).tolist()

print(len(uniq), uniq)
# Out:
# 22 ['action', 'adventure', 'avant garde', 'award winning', 'boys love', 'comedy', 'drama', 'ecchi', 'erotica', 'fantasy', 'girls love', 'gourmet', 'hentai', 'horror', 'mystery', 'romance', 'sci-fi', 'slice of life', 'sports', 'supernatural', 'suspense', 'unknown']

# %%
two_mode_df = create_two_mode_df(data)

two_mode_df
# Out:
#                                                   source         target
# 0                                           Cowboy Bebop         action
# 1                                           Cowboy Bebop  award winning
# 2                                           Cowboy Bebop         sci-fi
# 3                                Cowboy Bebop: The Movie         action
# 4                                Cowboy Bebop: The Movie         sci-fi
# ...                                                  ...            ...
# 30955  One Piece: Recapping Fierce Fights! The Counte...         action
# 30956  One Piece: Recapping Fierce Fights! The Counte...      adventure
# 30957  One Piece: Recapping Fierce Fights! The Counte...         comedy
# 30958  One Piece: Recapping Fierce Fights! The Counte...        fantasy
# 30959                                               Fins        unknown
#
# [30960 rows x 2 columns]

# %%
(weighted_matrix_np, weighted_matrix_index) = create_weighted_matrix2(two_mode_df)

# %%
weighted_matrix_df2 = pd.DataFrame(data=weighted_matrix_np, index=weighted_matrix_index, columns=weighted_matrix_index)

# %%
weighted_matrix_df2
# Out:
# source                                         "Deji" Meets Girl  \
# source
# "Deji" Meets Girl                                              1
# "Ippon" again!                                                 0
# "Parade" de Satie                                              0
# "Star"t                                                        0
# -OutsideR:RequieM-                                             0
# ...                                                          ...
# xxxHOLiC                                                       0
# xxxHOLiC The Movie: A Midsummer Night's Dream                  0
# ∀ Gundam                                                       0
# ∀ Gundam I: Earth Light                                        0
# ∀ Gundam II: Moonlight Butterfly                               0
#
# source                                         "Ippon" again!  \
# source
# "Deji" Meets Girl                                           0
# "Ippon" again!                                              1
# "Parade" de Satie                                           0
# "Star"t                                                     0
# -OutsideR:RequieM-                                          0
# ...                                                       ...
# xxxHOLiC                                                    0
# xxxHOLiC The Movie: A Midsummer Night's Dream               0
# ∀ Gundam                                                    0
# ∀ Gundam I: Earth Light                                     0
# ∀ Gundam II: Moonlight Butterfly                            0
#
# source                                         "Parade" de Satie  "Star"t  \
# source
# "Deji" Meets Girl                                              0        0
# "Ippon" again!                                                 0        0
# "Parade" de Satie                                              1        0
# "Star"t                                                        0        1
# -OutsideR:RequieM-                                             0        1
# ...                                                          ...      ...
# xxxHOLiC                                                       0        0
# xxxHOLiC The Movie: A Midsummer Night's Dream                  0        0
# ∀ Gundam                                                       0        0
# ∀ Gundam I: Earth Light                                        0        0
# ∀ Gundam II: Moonlight Butterfly                               0        0
#
# source                                         -OutsideR:RequieM-  .Koni-chan  \
# source
# "Deji" Meets Girl                                               0           0
# "Ippon" again!                                                  0           0
# "Parade" de Satie                                               0           0
# "Star"t                                                         1           0
# -OutsideR:RequieM-                                              1           0
# ...                                                           ...         ...
# xxxHOLiC                                                        0           1
# xxxHOLiC The Movie: A Midsummer Night's Dream                   0           1
# ∀ Gundam                                                        0           0
# ∀ Gundam I: Earth Light                                         0           0
# ∀ Gundam II: Moonlight Butterfly                                0           0
#
# source                                         .hack//G.U. Trilogy  \
# source
# "Deji" Meets Girl                                                0
# "Ippon" again!                                                   0
# "Parade" de Satie                                                0
# "Star"t                                                          0
# -OutsideR:RequieM-                                               0
# ...                                                            ...
# xxxHOLiC                                                         0
# xxxHOLiC The Movie: A Midsummer Night's Dream                    0
# ∀ Gundam                                                         1
# ∀ Gundam I: Earth Light                                          1
# ∀ Gundam II: Moonlight Butterfly                                 1
#
# source                                         .hack//G.U. Trilogy: Parody Mode  \
# source
# "Deji" Meets Girl                                                             0
# "Ippon" again!                                                                0
# "Parade" de Satie                                                             0
# "Star"t                                                                       0
# -OutsideR:RequieM-                                                            0
# ...                                                                         ...
# xxxHOLiC                                                                      1
# xxxHOLiC The Movie: A Midsummer Night's Dream                                 1
# ∀ Gundam                                                                      1
# ∀ Gundam I: Earth Light                                                       1
# ∀ Gundam II: Moonlight Butterfly                                              1
#
# source                                         .hack//Gift  \
# source
# "Deji" Meets Girl                                        0
# "Ippon" again!                                           0
# "Parade" de Satie                                        0
# "Star"t                                                  0
# -OutsideR:RequieM-                                       0
# ...                                                    ...
# xxxHOLiC                                                 1
# xxxHOLiC The Movie: A Midsummer Night's Dream            1
# ∀ Gundam                                                 0
# ∀ Gundam I: Earth Light                                  0
# ∀ Gundam II: Moonlight Butterfly                         0
#
# source                                         .hack//Legend of The Twilight  \
# source
# "Deji" Meets Girl                                                          0
# "Ippon" again!                                                             0
# "Parade" de Satie                                                          0
# "Star"t                                                                    0
# -OutsideR:RequieM-                                                         0
# ...                                                                      ...
# xxxHOLiC                                                                   1
# xxxHOLiC The Movie: A Midsummer Night's Dream                              1
# ∀ Gundam                                                                   1
# ∀ Gundam I: Earth Light                                                    0
# ∀ Gundam II: Moonlight Butterfly                                           0
#
# source                                         ...  selector spread WIXOSS  \
# source                                         ...
# "Deji" Meets Girl                              ...                       0
# "Ippon" again!                                 ...                       0
# "Parade" de Satie                              ...                       0
# "Star"t                                        ...                       1
# -OutsideR:RequieM-                             ...                       1
# ...                                            ...                     ...
# xxxHOLiC                                       ...                       0
# xxxHOLiC The Movie: A Midsummer Night's Dream  ...                       0
# ∀ Gundam                                       ...                       0
# ∀ Gundam I: Earth Light                        ...                       0
# ∀ Gundam II: Moonlight Butterfly               ...                       0
#
# source                                         sound / phantasma / mirror  \
# source
# "Deji" Meets Girl                                                       1
# "Ippon" again!                                                          0
# "Parade" de Satie                                                       0
# "Star"t                                                                 0
# -OutsideR:RequieM-                                                      0
# ...                                                                   ...
# xxxHOLiC                                                                0
# xxxHOLiC The Movie: A Midsummer Night's Dream                           0
# ∀ Gundam                                                                0
# ∀ Gundam I: Earth Light                                                 0
# ∀ Gundam II: Moonlight Butterfly                                        0
#
# source                                         teeter  the FLY BanD!  \
# source
# "Deji" Meets Girl                                   0              0
# "Ippon" again!                                      0              0
# "Parade" de Satie                                   0              0
# "Star"t                                             1              1
# -OutsideR:RequieM-                                  1              1
# ...                                               ...            ...
# xxxHOLiC                                            0              0
# xxxHOLiC The Movie: A Midsummer Night's Dream       0              0
# ∀ Gundam                                            0              0
# ∀ Gundam I: Earth Light                             0              0
# ∀ Gundam II: Moonlight Butterfly                    0              0
#
# source                                         tsuritama  xxxHOLiC  \
# source
# "Deji" Meets Girl                                      1         0
# "Ippon" again!                                         0         0
# "Parade" de Satie                                      0         0
# "Star"t                                                0         0
# -OutsideR:RequieM-                                     0         0
# ...                                                  ...       ...
# xxxHOLiC                                               1         4
# xxxHOLiC The Movie: A Midsummer Night's Dream          1         4
# ∀ Gundam                                               1         1
# ∀ Gundam I: Earth Light                                1         1
# ∀ Gundam II: Moonlight Butterfly                       1         1
#
# source                                         xxxHOLiC The Movie: A Midsummer Night's Dream  \
# source
# "Deji" Meets Girl                                                                          0
# "Ippon" again!                                                                             0
# "Parade" de Satie                                                                          0
# "Star"t                                                                                    0
# -OutsideR:RequieM-                                                                         0
# ...                                                                                      ...
# xxxHOLiC                                                                                   4
# xxxHOLiC The Movie: A Midsummer Night's Dream                                              4
# ∀ Gundam                                                                                   1
# ∀ Gundam I: Earth Light                                                                    1
# ∀ Gundam II: Moonlight Butterfly                                                           1
#
# source                                         ∀ Gundam  \
# source
# "Deji" Meets Girl                                     0
# "Ippon" again!                                        0
# "Parade" de Satie                                     0
# "Star"t                                               0
# -OutsideR:RequieM-                                    0
# ...                                                 ...
# xxxHOLiC                                              1
# xxxHOLiC The Movie: A Midsummer Night's Dream         1
# ∀ Gundam                                              6
# ∀ Gundam I: Earth Light                               3
# ∀ Gundam II: Moonlight Butterfly                      3
#
# source                                         ∀ Gundam I: Earth Light  \
# source
# "Deji" Meets Girl                                                    0
# "Ippon" again!                                                       0
# "Parade" de Satie                                                    0
# "Star"t                                                              0
# -OutsideR:RequieM-                                                   0
# ...                                                                ...
# xxxHOLiC                                                             1
# xxxHOLiC The Movie: A Midsummer Night's Dream                        1
# ∀ Gundam                                                             3
# ∀ Gundam I: Earth Light                                              3
# ∀ Gundam II: Moonlight Butterfly                                     3
#
# source                                         ∀ Gundam II: Moonlight Butterfly
# source
# "Deji" Meets Girl                                                             0
# "Ippon" again!                                                                0
# "Parade" de Satie                                                             0
# "Star"t                                                                       0
# -OutsideR:RequieM-                                                            0
# ...                                                                         ...
# xxxHOLiC                                                                      1
# xxxHOLiC The Movie: A Midsummer Night's Dream                                 1
# ∀ Gundam                                                                      3
# ∀ Gundam I: Earth Light                                                       3
# ∀ Gundam II: Moonlight Butterfly                                              3
#
# [7916 rows x 7916 columns]

# %%
weighted_matrix_df_pickle_file = "weighted_matrix_df.df"
if os.path.exists(weighted_matrix_df_pickle_file):
    weighted_matrix_df = pd.read_pickle(weighted_matrix_df_pickle_file)
else:
    weighted_matrix_df = weighted_matrix_df2
    weighted_matrix_df.to_pickle(weighted_matrix_df_pickle_file)

# %%
weighted_matrix_df
# Out:
# source                                         "Deji" Meets Girl  \
# source
# "Deji" Meets Girl                                              1
# "Ippon" again!                                                 0
# "Parade" de Satie                                              0
# "Star"t                                                        0
# -OutsideR:RequieM-                                             0
# ...                                                          ...
# xxxHOLiC                                                       0
# xxxHOLiC The Movie: A Midsummer Night's Dream                  0
# ∀ Gundam                                                       0
# ∀ Gundam I: Earth Light                                        0
# ∀ Gundam II: Moonlight Butterfly                               0
#
# source                                         "Ippon" again!  \
# source
# "Deji" Meets Girl                                           0
# "Ippon" again!                                              1
# "Parade" de Satie                                           0
# "Star"t                                                     0
# -OutsideR:RequieM-                                          0
# ...                                                       ...
# xxxHOLiC                                                    0
# xxxHOLiC The Movie: A Midsummer Night's Dream               0
# ∀ Gundam                                                    0
# ∀ Gundam I: Earth Light                                     0
# ∀ Gundam II: Moonlight Butterfly                            0
#
# source                                         "Parade" de Satie  "Star"t  \
# source
# "Deji" Meets Girl                                              0        0
# "Ippon" again!                                                 0        0
# "Parade" de Satie                                              1        0
# "Star"t                                                        0        1
# -OutsideR:RequieM-                                             0        1
# ...                                                          ...      ...
# xxxHOLiC                                                       0        0
# xxxHOLiC The Movie: A Midsummer Night's Dream                  0        0
# ∀ Gundam                                                       0        0
# ∀ Gundam I: Earth Light                                        0        0
# ∀ Gundam II: Moonlight Butterfly                               0        0
#
# source                                         -OutsideR:RequieM-  .Koni-chan  \
# source
# "Deji" Meets Girl                                               0           0
# "Ippon" again!                                                  0           0
# "Parade" de Satie                                               0           0
# "Star"t                                                         1           0
# -OutsideR:RequieM-                                              1           0
# ...                                                           ...         ...
# xxxHOLiC                                                        0           1
# xxxHOLiC The Movie: A Midsummer Night's Dream                   0           1
# ∀ Gundam                                                        0           0
# ∀ Gundam I: Earth Light                                         0           0
# ∀ Gundam II: Moonlight Butterfly                                0           0
#
# source                                         .hack//G.U. Trilogy  \
# source
# "Deji" Meets Girl                                                0
# "Ippon" again!                                                   0
# "Parade" de Satie                                                0
# "Star"t                                                          0
# -OutsideR:RequieM-                                               0
# ...                                                            ...
# xxxHOLiC                                                         0
# xxxHOLiC The Movie: A Midsummer Night's Dream                    0
# ∀ Gundam                                                         1
# ∀ Gundam I: Earth Light                                          1
# ∀ Gundam II: Moonlight Butterfly                                 1
#
# source                                         .hack//G.U. Trilogy: Parody Mode  \
# source
# "Deji" Meets Girl                                                             0
# "Ippon" again!                                                                0
# "Parade" de Satie                                                             0
# "Star"t                                                                       0
# -OutsideR:RequieM-                                                            0
# ...                                                                         ...
# xxxHOLiC                                                                      1
# xxxHOLiC The Movie: A Midsummer Night's Dream                                 1
# ∀ Gundam                                                                      1
# ∀ Gundam I: Earth Light                                                       1
# ∀ Gundam II: Moonlight Butterfly                                              1
#
# source                                         .hack//Gift  \
# source
# "Deji" Meets Girl                                        0
# "Ippon" again!                                           0
# "Parade" de Satie                                        0
# "Star"t                                                  0
# -OutsideR:RequieM-                                       0
# ...                                                    ...
# xxxHOLiC                                                 1
# xxxHOLiC The Movie: A Midsummer Night's Dream            1
# ∀ Gundam                                                 0
# ∀ Gundam I: Earth Light                                  0
# ∀ Gundam II: Moonlight Butterfly                         0
#
# source                                         .hack//Legend of The Twilight  \
# source
# "Deji" Meets Girl                                                          0
# "Ippon" again!                                                             0
# "Parade" de Satie                                                          0
# "Star"t                                                                    0
# -OutsideR:RequieM-                                                         0
# ...                                                                      ...
# xxxHOLiC                                                                   1
# xxxHOLiC The Movie: A Midsummer Night's Dream                              1
# ∀ Gundam                                                                   1
# ∀ Gundam I: Earth Light                                                    0
# ∀ Gundam II: Moonlight Butterfly                                           0
#
# source                                         ...  selector spread WIXOSS  \
# source                                         ...
# "Deji" Meets Girl                              ...                       0
# "Ippon" again!                                 ...                       0
# "Parade" de Satie                              ...                       0
# "Star"t                                        ...                       1
# -OutsideR:RequieM-                             ...                       1
# ...                                            ...                     ...
# xxxHOLiC                                       ...                       0
# xxxHOLiC The Movie: A Midsummer Night's Dream  ...                       0
# ∀ Gundam                                       ...                       0
# ∀ Gundam I: Earth Light                        ...                       0
# ∀ Gundam II: Moonlight Butterfly               ...                       0
#
# source                                         sound / phantasma / mirror  \
# source
# "Deji" Meets Girl                                                       1
# "Ippon" again!                                                          0
# "Parade" de Satie                                                       0
# "Star"t                                                                 0
# -OutsideR:RequieM-                                                      0
# ...                                                                   ...
# xxxHOLiC                                                                0
# xxxHOLiC The Movie: A Midsummer Night's Dream                           0
# ∀ Gundam                                                                0
# ∀ Gundam I: Earth Light                                                 0
# ∀ Gundam II: Moonlight Butterfly                                        0
#
# source                                         teeter  the FLY BanD!  \
# source
# "Deji" Meets Girl                                   0              0
# "Ippon" again!                                      0              0
# "Parade" de Satie                                   0              0
# "Star"t                                             1              1
# -OutsideR:RequieM-                                  1              1
# ...                                               ...            ...
# xxxHOLiC                                            0              0
# xxxHOLiC The Movie: A Midsummer Night's Dream       0              0
# ∀ Gundam                                            0              0
# ∀ Gundam I: Earth Light                             0              0
# ∀ Gundam II: Moonlight Butterfly                    0              0
#
# source                                         tsuritama  xxxHOLiC  \
# source
# "Deji" Meets Girl                                      1         0
# "Ippon" again!                                         0         0
# "Parade" de Satie                                      0         0
# "Star"t                                                0         0
# -OutsideR:RequieM-                                     0         0
# ...                                                  ...       ...
# xxxHOLiC                                               1         4
# xxxHOLiC The Movie: A Midsummer Night's Dream          1         4
# ∀ Gundam                                               1         1
# ∀ Gundam I: Earth Light                                1         1
# ∀ Gundam II: Moonlight Butterfly                       1         1
#
# source                                         xxxHOLiC The Movie: A Midsummer Night's Dream  \
# source
# "Deji" Meets Girl                                                                          0
# "Ippon" again!                                                                             0
# "Parade" de Satie                                                                          0
# "Star"t                                                                                    0
# -OutsideR:RequieM-                                                                         0
# ...                                                                                      ...
# xxxHOLiC                                                                                   4
# xxxHOLiC The Movie: A Midsummer Night's Dream                                              4
# ∀ Gundam                                                                                   1
# ∀ Gundam I: Earth Light                                                                    1
# ∀ Gundam II: Moonlight Butterfly                                                           1
#
# source                                         ∀ Gundam  \
# source
# "Deji" Meets Girl                                     0
# "Ippon" again!                                        0
# "Parade" de Satie                                     0
# "Star"t                                               0
# -OutsideR:RequieM-                                    0
# ...                                                 ...
# xxxHOLiC                                              1
# xxxHOLiC The Movie: A Midsummer Night's Dream         1
# ∀ Gundam                                              6
# ∀ Gundam I: Earth Light                               3
# ∀ Gundam II: Moonlight Butterfly                      3
#
# source                                         ∀ Gundam I: Earth Light  \
# source
# "Deji" Meets Girl                                                    0
# "Ippon" again!                                                       0
# "Parade" de Satie                                                    0
# "Star"t                                                              0
# -OutsideR:RequieM-                                                   0
# ...                                                                ...
# xxxHOLiC                                                             1
# xxxHOLiC The Movie: A Midsummer Night's Dream                        1
# ∀ Gundam                                                             3
# ∀ Gundam I: Earth Light                                              3
# ∀ Gundam II: Moonlight Butterfly                                     3
#
# source                                         ∀ Gundam II: Moonlight Butterfly
# source
# "Deji" Meets Girl                                                             0
# "Ippon" again!                                                                0
# "Parade" de Satie                                                             0
# "Star"t                                                                       0
# -OutsideR:RequieM-                                                            0
# ...                                                                         ...
# xxxHOLiC                                                                      1
# xxxHOLiC The Movie: A Midsummer Night's Dream                                 1
# ∀ Gundam                                                                      3
# ∀ Gundam I: Earth Light                                                       3
# ∀ Gundam II: Moonlight Butterfly                                              3
#
# [7916 rows x 7916 columns]

# %%
# weighted_df_pickle_file = "weighted_df.df"
# if os.path.exists(weighted_df_pickle_file):
#     weighted_df = pd.read_pickle(weighted_df_pickle_file)
# else:
#     weighted_df = create_weighted_df(weighted_matrix_df)
#     weighted_df.to_pickle(weighted_df_pickle_file)

# %%
# weighted_df

# %%
# weighted_df.columns

# %%
# for i in [3, 2, 1]:
# G = nx.from_pandas_edgelist(
#         weighted_df, source='source',
#         target='target', edge_attr='weight')

plt.figure(figsize=(35,35))

G = nx.from_numpy_array(weighted_matrix_np)
graph_pos = nx.spring_layout(G)
nx.draw_networkx_nodes(G, graph_pos, node_size=10, node_color='blue', alpha=0.3)
nx.draw_networkx_edges(G, graph_pos)
nx.draw_networkx_labels(G, graph_pos, font_size=8, font_family='sans-serif')

# plt.show()

# nx.draw(G)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 11
#       9 graph_pos = nx.spring_layout(G)
#      10 nx.draw_networkx_nodes(G, graph_pos, node_size=10, node_color='blue', alpha=0.3)
# ---> 11 nx.draw_networkx_edges(G, graph_pos)
#      12 nx.draw_networkx_labels(G, graph_pos, font_size=8, font_family='sans-serif')
#      14 # plt.show()
#      15
#      16 # nx.draw(G)
#
# File ~/.pyenv/versions/3.11.6/envs/ml-anime/lib/python3.11/site-packages/networkx/drawing/nx_pylab.py:902, in draw_networkx_edges(G, pos, edgelist, width, edge_color, style, alpha, arrowstyle, arrowsize, edge_cmap, edge_vmin, edge_vmax, ax, arrows, label, node_size, nodelist, node_shape, connectionstyle, min_source_margin, min_target_margin)
#     900 edge_viz_obj = _draw_networkx_edges_line_collection()
#     901 # Make sure selfloop edges are also drawn
# --> 902 selfloops_to_draw = [loop for loop in nx.selfloop_edges(G) if loop in edgelist]
#     903 if selfloops_to_draw:
#     904     fancy_edges_indices = [
#     905         edgelist_tuple.index(loop) for loop in selfloops_to_draw
#     906     ]
#
# File ~/.pyenv/versions/3.11.6/envs/ml-anime/lib/python3.11/site-packages/networkx/drawing/nx_pylab.py:902, in <listcomp>(.0)
#     900 edge_viz_obj = _draw_networkx_edges_line_collection()
#     901 # Make sure selfloop edges are also drawn
# --> 902 selfloops_to_draw = [loop for loop in nx.selfloop_edges(G) if loop in edgelist]
#     903 if selfloops_to_draw:
#     904     fancy_edges_indices = [
#     905         edgelist_tuple.index(loop) for loop in selfloops_to_draw
#     906     ]
#
# KeyboardInterrupt:

# %%
plt.savefig("plot.svg", dpi=1200)

# %%
net = Network(notebook=True)
net.from_nx(G)
net.show("example.html")
