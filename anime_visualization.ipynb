# %%
# Standard IPython notebook imports
# %matplotlib inline

import os
import csv
import math
import ast
import json
import shutil

import pyarrow
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import sklearn.metrics

import subprocess

from tqdm.notebook import tqdm
from itertools import chain
from typing import Optional

pd.options.display.max_colwidth = 300

# %%
USERS_CSV="dataset/user-filtered.csv"
ANIME_CSV="dataset/anime-dataset-2023.csv"

# %%
def load_pd(filepath, line_count: int | None):
    return pd.read_csv(filepath, sep=',', nrows=line_count)

# %%
# %%time
LINES = 10000000

users_df = load_pd(USERS_CSV, LINES)
animes_df = load_pd(ANIME_CSV, None)

# is user data loaded?
len(users_df)
len(animes_df)
# Out:
# CPU times: user 1.36 s, sys: 290 ms, total: 1.65 s
# Wall time: 1.73 s
# 24905

# %%
class AnimeRecomendation:
    def __init__(self, users_df=pd.DataFrame(), animes_df=pd.DataFrame()):
        self.users_df = users_df
        self.animes_df = animes_df
        self.users_count = None
        self.columns = ['user', 'anime']
        self.grouped_columns = ['user_id', 'anime_id']
        self.tsv_filename = None
        self.popularity_threshold = 6000

    def change_data(self, users_df, animes_df):
        self.users_df = users_df
        self.animes_df = animes_df

        return self.number_of_users()

    def from_csv(self, file: str):
        self.tsv_filename = file
        self.grouped_df = pd.read_csv(file,
                                      sep="\t",
                                      header=None,
                                      names=self.grouped_columns)

    def choose(self, nousers: int):
        if nousers <= self.number_of_users():
            self.users_df = self.users_df.sample(n=nousers)

    def number_of_users(self):
        if self.users_count is None:
            self.users_count = self.users_df.max()['user_id']
        return self.users_count

    def fit(self, rating_threshold=6):

        def adj_mult(rating: int) -> int:
            match rating:
                case 6 | 7: return 1
                case 8 | 9: return 2
                case 10: return 3
                case _: return 0

        def agg_fun(anime: str, rating: int) -> str:
            return " ".join([str(anime)] * adj_mult(rating))


        self.animes_df = self.animes_df[(self.animes_df['Popularity'] <= self.popularity_threshold) &
                                        (self.animes_df['Popularity'] > 0)]

        self.users_df = self.users_df[self.users_df['rating'] >= rating_threshold]
        self.users_df = self.users_df[self.users_df['anime_id'].isin(self.animes_df['anime_id'])]
        self.animes_df = self.animes_df[self.animes_df['anime_id'].isin(self.users_df['anime_id'])]

        self.users_df = (self.users_df
            .assign(id_rating=lambda x: list(zip(x['anime_id'], x['rating'])))
            .groupby('user_id')['id_rating']
            .agg(lambda animes: " ".join([agg_fun(anime, rating) for (anime, rating) in animes]))
            .reset_index()
            .rename(columns={'id_rating': 'anime_id'}))

        self.animes_df = (self.animes_df
            .assign(genre=lambda x: x['Genres'].apply(lambda x: list(map(str.strip, x.split(",")))))
            .filter(items=['anime_id', 'genre'])
            .explode('genre')
            .groupby('genre')
            .agg(lambda genres: " ".join([str(i) for i in genres]))
            .reset_index()
            .rename(columns={'genre': 'user_id'}))

        self.grouped_df = self.users_df

        return self.number_of_users()

    def save_to_tsv(self, tsv_filename: str):
        self.tsv_filename = tsv_filename
        self.grouped_df.to_csv(self.tsv_filename,
                               index=False,
                               sep='\t',
                               columns=self.grouped_columns,
                               mode='w',
                               header=False)
        self.animes_df.to_csv("animes.tsv",
                               index=False,
                               sep='\t',
                               columns=self.grouped_columns,
                               mode='w',
                               header=False)

    def cleora_train(self, cleora_exe="./cleora-exe", dimensions=32, iter=16):
        if self.tsv_filename is None:
            raise RuntimeError("TSV filename not yet created")
        if not os.access(cleora_exe, os.X_OK) and shutil.which(cleora_exe) is None:
            raise RuntimeError(f"cleora executable not found: {cleora_exe}")

        command = [cleora_exe,
                   "--type", "tsv",
                   f"--columns=transient::{self.columns[0]} complex::{self.columns[1]}",
                   "--dimension", str(dimensions),
                   "--number-of-iterations", str(iter),
                   "--prepend-field-name", "0",
                   "-f", "numpy",
                   "-o", "results",
                   "-e", "1",
                   self.tsv_filename]
        subprocess.run(command, check=True)

        command = [cleora_exe,
                   "--type", "tsv",
                   f"--columns=transient::genre complex::anime",
                   "--dimension", "8",
                   "--number-of-iterations", str(iter),
                   "--prepend-field-name", "0",
                   "-f", "numpy",
                   "-o", "results",
                   "-e", "1",
                   "animes.tsv"]
        subprocess.run(command, check=True)

# %%
model = AnimeRecomendation(users_df=users_df, animes_df=animes_df)

# %%
# %%time
RATING_THRESHOLD = 6

model.fit(rating_threshold=RATING_THRESHOLD)
# Out:
# False
# False
# True
# False
# False
# CPU times: user 7.24 s, sys: 296 ms, total: 7.53 s
# Wall time: 7.53 s
# 32600

# %%
x = model.users_df['anime_id'].apply(lambda x: x.split(' ')).explode().unique()
x.sort()
y = model.animes_df['anime_id'].apply(lambda x: x.split(' ')).explode().unique()
y.sort()
np.all(x == y)
# Out:
# True

# %%
# %%time
# constructing the tsv data

tsv_file_name = "data.tsv"
model.save_to_tsv(tsv_file_name)
# Out:
# CPU times: user 713 ms, sys: 52.5 ms, total: 765 ms
# Wall time: 831 ms

# %%
# %%time

CLEORA_EXE = './cleora-exe'
DIMENSIONS = 64
ITER = 64

# You shouldnt be running it every time!

# Commented it out for safety reasons xd
model.cleora_train(cleora_exe=CLEORA_EXE, dimensions=DIMENSIONS, iter=ITER)
# Out:
# [2024-02-11T15:58:58Z INFO  cleora] Reading args...
# [src/main.rs:222] &config = Configuration {
#     produce_entity_occurrence_count: true,
#     embeddings_dimension: 64,
#     max_number_of_iteration: 64,
#     seed: None,
#     prepend_field: false,
#     log_every_n: 10000,
#     in_memory_embedding_calculation: true,
#     input: [
#         "data.tsv",
#     ],
#     file_type: Tsv,
#     output_dir: Some(
#         "results",
#     ),
#     output_format: Numpy,
#     relation_name: "emb",
#     columns: [
#         Column {
#             name: "user",
#             transient: true,
#             complex: false,
#             reflexive: false,
#             ignored: false,
#         },
#         Column {
#             name: "anime",
#             transient: false,
#             complex: true,
#             reflexive: false,
#             ignored: false,
#         },
#     ],
# }
# [2024-02-11T15:58:58Z INFO  cleora] Starting calculation...
# [src/pipeline.rs:25] &sparse_matrices = [
#     SparseMatrix {
#         col_a_id: 0,
#         col_a_name: "user",
#         col_b_id: 1,
#         col_b_name: "anime",
#         edge_count: 0,
#         hash_2_id: {},
#         id_2_hash: [],
#         row_sum: [],
#         pair_index: {},
#         entries: [],
#     },
# ]
# [2024-02-11T15:58:59Z INFO  cleora::pipeline] Number of lines processed: 10000
# [2024-02-11T15:58:59Z INFO  cleora::pipeline] Number of lines processed: 20000
# [2024-02-11T15:59:00Z INFO  cleora::sparse_matrix] Number of entities: 34120
# [2024-02-11T15:59:00Z INFO  cleora::sparse_matrix] Number of edges: 8454163
# [2024-02-11T15:59:00Z INFO  cleora::sparse_matrix] Number of entries: 9707338
# [2024-02-11T15:59:00Z INFO  cleora::sparse_matrix] Total memory usage by the struct ~ 361 MB
# [2024-02-11T15:59:00Z INFO  cleora] Finished Sparse Matrices calculation in 2 sec
# [2024-02-11T15:59:00Z INFO  cleora::embedding] Start initialization. Dims: 64, entities: 34120.
# [2024-02-11T15:59:00Z INFO  cleora::embedding] Done initializing. Dims: 64, entities: 34120.
# [2024-02-11T15:59:00Z INFO  cleora::embedding] Start propagating. Number of iterations: 64.
# [2024-02-11T15:59:01Z INFO  cleora::embedding] Done iter: 0. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:01Z INFO  cleora::embedding] Done iter: 1. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:01Z INFO  cleora::embedding] Done iter: 2. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:02Z INFO  cleora::embedding] Done iter: 3. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:02Z INFO  cleora::embedding] Done iter: 4. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:03Z INFO  cleora::embedding] Done iter: 5. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:03Z INFO  cleora::embedding] Done iter: 6. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:03Z INFO  cleora::embedding] Done iter: 7. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:04Z INFO  cleora::embedding] Done iter: 8. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:04Z INFO  cleora::embedding] Done iter: 9. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:05Z INFO  cleora::embedding] Done iter: 10. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:05Z INFO  cleora::embedding] Done iter: 11. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:06Z INFO  cleora::embedding] Done iter: 12. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:06Z INFO  cleora::embedding] Done iter: 13. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:07Z INFO  cleora::embedding] Done iter: 14. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:07Z INFO  cleora::embedding] Done iter: 15. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:08Z INFO  cleora::embedding] Done iter: 16. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:08Z INFO  cleora::embedding] Done iter: 17. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:09Z INFO  cleora::embedding] Done iter: 18. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:09Z INFO  cleora::embedding] Done iter: 19. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:10Z INFO  cleora::embedding] Done iter: 20. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:10Z INFO  cleora::embedding] Done iter: 21. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:11Z INFO  cleora::embedding] Done iter: 22. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:11Z INFO  cleora::embedding] Done iter: 23. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:12Z INFO  cleora::embedding] Done iter: 24. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:12Z INFO  cleora::embedding] Done iter: 25. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:13Z INFO  cleora::embedding] Done iter: 26. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:13Z INFO  cleora::embedding] Done iter: 27. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:14Z INFO  cleora::embedding] Done iter: 28. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:14Z INFO  cleora::embedding] Done iter: 29. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:15Z INFO  cleora::embedding] Done iter: 30. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:16Z INFO  cleora::embedding] Done iter: 31. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:16Z INFO  cleora::embedding] Done iter: 32. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:17Z INFO  cleora::embedding] Done iter: 33. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:17Z INFO  cleora::embedding] Done iter: 34. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:18Z INFO  cleora::embedding] Done iter: 35. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:18Z INFO  cleora::embedding] Done iter: 36. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:19Z INFO  cleora::embedding] Done iter: 37. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:19Z INFO  cleora::embedding] Done iter: 38. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:20Z INFO  cleora::embedding] Done iter: 39. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:20Z INFO  cleora::embedding] Done iter: 40. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:21Z INFO  cleora::embedding] Done iter: 41. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:21Z INFO  cleora::embedding] Done iter: 42. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:22Z INFO  cleora::embedding] Done iter: 43. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:22Z INFO  cleora::embedding] Done iter: 44. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:23Z INFO  cleora::embedding] Done iter: 45. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:23Z INFO  cleora::embedding] Done iter: 46. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:24Z INFO  cleora::embedding] Done iter: 47. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:25Z INFO  cleora::embedding] Done iter: 48. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:25Z INFO  cleora::embedding] Done iter: 49. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:26Z INFO  cleora::embedding] Done iter: 50. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:26Z INFO  cleora::embedding] Done iter: 51. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:27Z INFO  cleora::embedding] Done iter: 52. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:27Z INFO  cleora::embedding] Done iter: 53. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:28Z INFO  cleora::embedding] Done iter: 54. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:28Z INFO  cleora::embedding] Done iter: 55. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:29Z INFO  cleora::embedding] Done iter: 56. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:30Z INFO  cleora::embedding] Done iter: 57. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:30Z INFO  cleora::embedding] Done iter: 58. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:31Z INFO  cleora::embedding] Done iter: 59. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:31Z INFO  cleora::embedding] Done iter: 60. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:32Z INFO  cleora::embedding] Done iter: 61. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:32Z INFO  cleora::embedding] Done iter: 62. Dims: 64, entities: 34120, num data points: 9707338.
# CPU times: user 184 ms, sys: 19.6 ms, total: 204 ms
# Wall time: 34.9 s
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 63. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done propagating.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Start saving embeddings.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done saving embeddings.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Finalizing embeddings calculations!
# [2024-02-11T15:59:33Z INFO  cleora] Finished in 34 sec
# [2024-02-11T15:59:33Z INFO  cleora] Reading args...
# [src/main.rs:222] &config = Configuration {
#     produce_entity_occurrence_count: true,
#     embeddings_dimension: 8,
#     max_number_of_iteration: 64,
#     seed: None,
#     prepend_field: false,
#     log_every_n: 10000,
#     in_memory_embedding_calculation: true,
#     input: [
#         "animes.tsv",
#     ],
#     file_type: Tsv,
#     output_dir: Some(
#         "results",
#     ),
#     output_format: Numpy,
#     relation_name: "emb",
#     columns: [
#         Column {
#             name: "genre",
#             transient: true,
#             complex: false,
#             reflexive: false,
#             ignored: false,
#         },
#         Column {
#             name: "anime",
#             transient: false,
#             complex: true,
#             reflexive: false,
#             ignored: false,
#         },
#     ],
# }
# [2024-02-11T15:59:33Z INFO  cleora] Starting calculation...
# [src/pipeline.rs:25] &sparse_matrices = [
#     SparseMatrix {
#         col_a_id: 0,
#         col_a_name: "genre",
#         col_b_id: 1,
#         col_b_name: "anime",
#         edge_count: 0,
#         hash_2_id: {},
#         id_2_hash: [],
#         row_sum: [],
#         pair_index: {},
#         entries: [],
#     },
# ]
# [2024-02-11T15:59:33Z INFO  cleora::sparse_matrix] Number of entities: 5308
# [2024-02-11T15:59:33Z INFO  cleora::sparse_matrix] Number of edges: 13069
# [2024-02-11T15:59:33Z INFO  cleora::sparse_matrix] Number of entries: 26138
# [2024-02-11T15:59:33Z INFO  cleora::sparse_matrix] Total memory usage by the struct ~ 0 MB
# [2024-02-11T15:59:33Z INFO  cleora] Finished Sparse Matrices calculation in 0 sec
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Start initialization. Dims: 8, entities: 5308.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done initializing. Dims: 8, entities: 5308.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Start propagating. Number of iterations: 64.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 0. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 1. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 2. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 3. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 4. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 5. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 6. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 7. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 8. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 9. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 10. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 11. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 12. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 13. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 14. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 15. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 16. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 17. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 18. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 19. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 20. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 21. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 22. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 23. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 24. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 25. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 26. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 27. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 28. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 29. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 30. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 31. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 32. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 33. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 34. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 35. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 36. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 37. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 38. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 39. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 40. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 41. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 42. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 43. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 44. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 45. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 46. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 47. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 48. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 49. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 50. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 51. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 52. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 53. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 54. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 55. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 56. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 57. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 58. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 59. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 60. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 61. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 62. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done iter: 63. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done propagating.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Start saving embeddings.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Done saving embeddings.
# [2024-02-11T15:59:33Z INFO  cleora::embedding] Finalizing embeddings calculations!
# [2024-02-11T15:59:33Z INFO  cleora] Finished in 0 sec

# %%
class RatingGenerator:
    def __init__(self):
        self.users_count = None
        self.columns = ["user", "anime"]
        self.rankings = dict()

    def get_artifacts(self):
        p = "results/emb__"
        files = ["labels", "vects_iter"]
        suf = [".out.entities", ".out.npy"]

        return {'users': {f: f"{p}{self.columns[0]}__{self.columns[1]}{suf[idx]}"
                            for idx, f in enumerate(files)},
                'genres': {f: f"{p}genre__anime{suf[idx]}"
                            for idx, f in enumerate(files)}}

    def load_artifacts(self):
        artifacts = self.get_artifacts()
        with open(artifacts['users']['labels'], "r") as entities:
            self.labels = np.array([int(i) for i in json.load(entities)])

        with open(artifacts['genres']['labels'], "r") as entities:
            self.glabels = glabels = np.array([int(i) for i in json.load(entities)])

            glabels = self.glabels
            glabels = self.glabels
            glabels = self.glabels        # Load results to numpy
        self.vects_iter = np.load(artifacts['users']['vects_iter'])
        self.gvects_iter = np.load(artifacts['genres']['vects_iter'])

        self.vects_iter = self.vects_iter[self.labels.argsort()]
        self.labels.sort()

        self.gvects_iter = self.gvects_iter[glabels.argsort()]
        glabels.sort()

        # assert np.all(self.labels == glabels)


    def load_rankings(self, idx: int):
        real_id = np.where(self.labels == idx)[0][0]

        uv = self.vects_iter[real_id]
        udist = sklearn.metrics.pairwise.cosine_similarity(uv.reshape(1, -1),
                                                          self.vects_iter,
                                                          dense_output=True)

        gv = self.gvects_iter[real_id]
        gdist = sklearn.metrics.pairwise.cosine_similarity(gv.reshape(1, -1),
                                                           self.gvects_iter,
                                                           dense_output=True)

        dist = udist[0] + 0.2 * gdist[0]

        ranking = (-dist).argsort()

        self.rankings[idx] = self.labels[ranking[:15]]

    def add_to_custom_ranking(self, custom_ranking, idx: int):
        anime_ranking = self.rankings[idx]

        for anime in anime_ranking:
            if anime in custom_ranking:
                custom_ranking[anime] += 1
            else:
                custom_ranking[anime] = 1

    def predict(self, already_watched):

        self.load_artifacts()
        custom_ranking = dict()

        for idx in tqdm(already_watched):
            if idx not in self.rankings:
                self.load_rankings(idx)

            self.add_to_custom_ranking(custom_ranking, idx)

        return dict(sorted(custom_ranking.items(),
                           reverse=True,
                           key=lambda x: x[1]))

# %%
rg = RatingGenerator()
rg.load_artifacts()
rg.glabels, rg.labels

# %%
# Ranking

ratingGenerator = RatingGenerator()

def pandas_extract_content(row, label):
    name = row[label].to_string()
    return name.split("    ")[1]

ranking = ratingGenerator.predict([67, 6702, 242])
for label, times in ranking.items():
    filter = anime_df[anime_df.anime_id == label]
    if len(filter) == 0:
        continue

    print(f"{pandas_extract_content(filter, 'Name')}: {times}")

# %%
def extract_year(aired):
    return aired.split(",")[1].split(" ")[1]

def search_str(s, search):
    return search in str(s).lower()

def find_in_rows(name):
    name = name.lower()
    mask = anime_df.apply(lambda x: x.map(lambda s: search_str(s, name)))
    return anime_df.loc[mask.any(axis=1)]

def find_by_name(name):
    return anime_df[anime_df['Name'].str.lower().str.contains(name.lower(), na=False)]
    
find_by_name("Shingeki no Kyojin").head(10).anime_id
