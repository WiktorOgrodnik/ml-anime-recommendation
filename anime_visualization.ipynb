# %%
# Standard IPython notebook imports
# %matplotlib inline

import os
import csv
import math
import ast
import json
import shutil

import pyarrow
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import sklearn.metrics

import subprocess

from tqdm.notebook import tqdm
from itertools import chain
from typing import Optional

pd.options.display.max_colwidth = 300

# %%
users_csv="dataset/user-filtered.csv"
users_df = pd.read_csv(users_csv, sep=",")

# %%
users_df.head() # is user data loaded?
len(users_df)
# Out:
# 109224747

# %%
class AnimeRecomendation:
    def __init__(self):
        self.users_df = pd.DataFrame()
        self.users_count = None
        self.columns = ["user", "anime"]
        self.grouped_columns = ["user_id", "id_rating"]  
        self.tsv_filename = None
        
    def number_of_users(self):
        if self.users_count is None:
            self.users_count = self.users_df.max()['user_id']
        return self.users_count

    def save_to_tsv(self, tsv_filename: str):
        self.tsv_filename = tsv_filename
        self.grouped_df.to_csv(self.tsv_filename,
                               index=False,
                               sep='\t',
                               columns=self.grouped_columns,
                               mode='w',
                               header=False)

    def fit(self, users_df, lines: Optional[int] = None, rating_threshold: int = 6):

        self.users_df = users_df.head(int(lines)) if lines is not None else users_df

        def adj_mult(rating: int) -> int:
            match rating:
                case 6 | 7: return 1
                case 8 | 9: return 2
                case 10: return 3
                case _: return 0
    
        def agg_fun(anime: str, rating: int) -> str:
            return " ".join([str(anime)] * adj_mult(rating))

        self.users_df['id_rating'] = list(zip(self.users_df['anime_id'], self.users_df['rating']))

        self.grouped_df = self.users_df[self.users_df.rating >= rating_threshold]                \
            .groupby("user_id")["id_rating"]                                                     \
            .agg(lambda animes: " ".join([agg_fun(anime, rating) for (anime,rating) in animes])) \
            .reset_index()

        return self.number_of_users()

    def from_csv(self, file: str):
        self.grouped_df = pd.read_csv(file,
                                      sep="\t",
                                      header=None,
                                      names=self.grouped_columns)
    
    def choose(self, nousers: int):
        self.grouped_df = self.grouped_df.sample(n=nousers)
    
    def cleora_train(self, cleora_exe="cleora", dimensions = 32, iter = 16):
        if self.tsv_filename is None:
            raise RuntimeError("TSV filename not yet created")
        if not os.access(cleora_exe, os.X_OK) and shutil.which(cleora_exe) is None:
            raise RuntimeError("cleora executable not found")

        command = [cleora_exe,
                   "--type", "tsv",
                   f"--columns=transient::{self.columns[0]} complex::{self.columns[1]}",
                   "--dimension", str(dimensions),
                   "--number-of-iterations", str(iter),
                   "--prepend-field-name", "0",
                   "-f", "numpy",
                   "-o", "results",
                   "-e", "1",
                   self.tsv_filename]
        subprocess.run(command, check=True)

# %%
model = AnimeRecomendation()

# %%
# %%time

LINES = 40000000
RATING_THRESHOLD = 6

model.fit(users_df, lines=LINES, rating_threshold=RATING_THRESHOLD)
# Out:
# /tmp/ipykernel_91172/1232305359.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.users_df['id_rating'] = list(zip(self.users_df['anime_id'], self.users_df['rating']))
# CPU times: user 50.6 s, sys: 1.91 s, total: 52.5 s
# Wall time: 52.7 s
# 129988

# %%
model.choose(20000)
model.grouped_df
# Out:
#         user_id  \
# 46121     52057
# 110191   124385
# 92443    104444
# 108375   122319
# 9655      10930
# ...         ...
# 41226     46539
# 89685    101346
# 38597     43564
# 39187     44221
# 89892    101574
#
#                                                                                                                                                                                                                                                                                                           id_rating
# 46121   39792 39792 42203 42203 41762 41762 6547 9989 31964 31964 33486 33486 38186 28999 14741 18671 18671 16934 2167 4059 4059 4059 1575 1575 26349 26349 26349 35849 35849 37982 37982 38145 38544 3784 3784 3785 227 227 38680 38680 71 37998 39417 39417 17729 10793 31859 934 934 185 185 38472 14719 2089...
# 110191  36456 36456 35760 35760 30123 31173 22199 19429 6547 24833 30654 21995 30205 31754 31964 31964 33486 33486 21405 33056 34173 28999 34382 32189 33028 16592 11843 35849 9982 74 28825 6008 7054 10298 9366 32281 34389 33489 585 16067 36038 34383 31414 20507 30503 20767 26243 28927 30015 36752 13759 ...
# 92443   34572 34572 38101 38101 30123 30123 31173 31173 22199 22199 22147 6547 6547 9989 9989 15039 15039 11111 24833 30654 30654 28405 9919 33506 7817 7817 32827 5081 20787 20787 269 31043 31043 31964 33486 36456 38186 14345 28999 28999 34382 34382 38940 35849 35849 6880 6880 1535 1535 28223 28223 3512...
# 108375  42897 42897 40748 40748 21 21 39617 37956 38101 22147 22147 9989 9989 9989 9919 36882 5081 5081 5081 10330 889 889 1519 1519 269 269 11633 40060 31043 31043 31964 31964 33486 36456 36456 38408 42603 10719 14967 31478 32867 38003 10163 28999 28999 30485 10800 10800 39523 14741 14741 15583 1535 15...
# 9655    457 457 457 20767 20767 18179 12291 16273 101 101 102 19429 6547 6547 9919 9919 11266 8475 8475 8475 269 269 269 31964 31964 31964 1222 1222 1689 1689 1689 59 14741 14741 14741 18671 18671 61 6880 6880 6880 1535 1535 28223 28223 28223 5593 5593 30346 30346 30346 18507 18507 243 8768 15895 15895 ...
# ...                                                                                                                                                                                                                                                                                                             ...
# 41226   21 21 32998 30123 22199 26449 25013 41433 6547 9062 35015 37924 39959 42238 9989 9989 11111 11701 24833 30654 30654 19759 21995 21995 9919 11737 33506 28249 31821 39195 39195 13535 530 740 532 1239 996 20787 11633 40060 31043 31043 31964 1222 14345 14345 31478 31478 32867 32867 38003 38003 33071...
# 89685   33975 33975 33975 30829 30829 20913 20913 36904 36904 37769 47 47 47 6547 9989 9989 9989 7475 11111 11111 21995 21995 21995 9919 9919 7647 7647 9074 9074 1028 1028 36214 36214 5168 37171 37171 37171 37996 38002 38002 38002 9736 10582 586 7817 28805 28805 5081 5081 5081 7674 7674 34636 36649 3664...
# 38597   30654 31964 31964 30694 30694 31798 31798 28623 31741 31741 31772 31772 31240 31240 32595 31327 32105 31430 31098 31098 5525 6682 25397 22199 22199 24833 9919 9919 11737 11737 13677 11266 11266 10647 20787 31043 31043 31478 31478 28999 28999 31553 31553 31636 6880 1535 28223 29589 31710 223 223 ...
# 39187   1470 1470 1470 1491 1491 1491 2998 2998 170 170 47 47 47 1348 1348 2755 2755 1661 1661 1661 1030 1030 1030 1358 1358 1358 431 431 731 731 731 3220 3220 3220 572 572 43 43 416 416 1430 1430 1430 522 522 522 875 875 323 323 30 30 30 437 437 437 210 210 2000 2000 2000 199 199 199 2154 2154 2154 513...
# 89892   48 48 1292 1292 4970 4970 47 47 54 54 2969 2969 3446 3446 3446 1686 1686 2889 2889 405 998 998 1536 5356 5356 1575 1575 2904 2904 1 1 974 974 1535 1535 1726 1726 813 813 226 226 317 317 317 2952 2952 2952 408 408 1361 227 227 227 121 121 5114 5114 5114 384 384 395 270 270 431 431 431 468 468 617...
#
# [20000 rows x 2 columns]

# %%
# %%time
# constructing the tsv data

tsv_file_name = "data2.tsv"
model.save_to_tsv(tsv_file_name)
# Out:
# CPU times: user 954 ms, sys: 59.8 ms, total: 1.01 s
# Wall time: 1.07 s

# %%
# %%time

# You shouldnt be running it every time!

# Commented it out for safety reasons xd
model.cleora_train()
# Out:
# [2024-02-07T23:50:42Z INFO  cleora] Reading args...
# [src/main.rs:222] &config = Configuration {
#     produce_entity_occurrence_count: true,
#     embeddings_dimension: 32,
#     max_number_of_iteration: 16,
#     seed: None,
#     prepend_field: false,
#     log_every_n: 10000,
#     in_memory_embedding_calculation: true,
#     input: [
#         "data2.tsv",
#     ],
#     file_type: Tsv,
#     output_dir: Some(
#         "results",
#     ),
#     output_format: Numpy,
#     relation_name: "emb",
#     columns: [
#         Column {
#             name: "user",
#             transient: true,
#             complex: false,
#             reflexive: false,
#             ignored: false,
#         },
#         Column {
#             name: "anime",
#             transient: false,
#             complex: true,
#             reflexive: false,
#             ignored: false,
#         },
#     ],
# }
# [2024-02-07T23:50:42Z INFO  cleora] Starting calculation...
# [src/pipeline.rs:25] &sparse_matrices = [
#     SparseMatrix {
#         col_a_id: 0,
#         col_a_name: "user",
#         col_b_id: 1,
#         col_b_name: "anime",
#         edge_count: 0,
#         hash_2_id: {},
#         id_2_hash: [],
#         row_sum: [],
#         pair_index: {},
#         entries: [],
#     },
# ]
# [2024-02-07T23:50:43Z INFO  cleora::pipeline] Number of lines processed: 10000
# [2024-02-07T23:50:44Z INFO  cleora::pipeline] Number of lines processed: 20000
# [2024-02-07T23:50:44Z INFO  cleora::sparse_matrix] Number of entities: 34246
# [2024-02-07T23:50:44Z INFO  cleora::sparse_matrix] Number of edges: 6052893
# [2024-02-07T23:50:44Z INFO  cleora::sparse_matrix] Number of entries: 7009582
# [2024-02-07T23:50:44Z INFO  cleora::sparse_matrix] Total memory usage by the struct ~ 181 MB
# [2024-02-07T23:50:44Z INFO  cleora] Finished Sparse Matrices calculation in 1 sec
# [2024-02-07T23:50:44Z INFO  cleora::embedding] Start initialization. Dims: 32, entities: 34246.
# [2024-02-07T23:50:44Z INFO  cleora::embedding] Done initializing. Dims: 32, entities: 34246.
# [2024-02-07T23:50:44Z INFO  cleora::embedding] Start propagating. Number of iterations: 16.
# [2024-02-07T23:50:44Z INFO  cleora::embedding] Done iter: 0. Dims: 32, entities: 34246, num data points: 7009582.
# [2024-02-07T23:50:44Z INFO  cleora::embedding] Done iter: 1. Dims: 32, entities: 34246, num data points: 7009582.
# [2024-02-07T23:50:44Z INFO  cleora::embedding] Done iter: 2. Dims: 32, entities: 34246, num data points: 7009582.
# [2024-02-07T23:50:44Z INFO  cleora::embedding] Done iter: 3. Dims: 32, entities: 34246, num data points: 7009582.
# [2024-02-07T23:50:44Z INFO  cleora::embedding] Done iter: 4. Dims: 32, entities: 34246, num data points: 7009582.
# [2024-02-07T23:50:44Z INFO  cleora::embedding] Done iter: 5. Dims: 32, entities: 34246, num data points: 7009582.
# [2024-02-07T23:50:45Z INFO  cleora::embedding] Done iter: 6. Dims: 32, entities: 34246, num data points: 7009582.
# [2024-02-07T23:50:45Z INFO  cleora::embedding] Done iter: 7. Dims: 32, entities: 34246, num data points: 7009582.
# [2024-02-07T23:50:45Z INFO  cleora::embedding] Done iter: 8. Dims: 32, entities: 34246, num data points: 7009582.
# [2024-02-07T23:50:45Z INFO  cleora::embedding] Done iter: 9. Dims: 32, entities: 34246, num data points: 7009582.
# [2024-02-07T23:50:45Z INFO  cleora::embedding] Done iter: 10. Dims: 32, entities: 34246, num data points: 7009582.
# [2024-02-07T23:50:45Z INFO  cleora::embedding] Done iter: 11. Dims: 32, entities: 34246, num data points: 7009582.
# [2024-02-07T23:50:45Z INFO  cleora::embedding] Done iter: 12. Dims: 32, entities: 34246, num data points: 7009582.
# [2024-02-07T23:50:45Z INFO  cleora::embedding] Done iter: 13. Dims: 32, entities: 34246, num data points: 7009582.
# CPU times: user 12.6 ms, sys: 5.02 ms, total: 17.7 ms
# Wall time: 3.44 s
# [2024-02-07T23:50:45Z INFO  cleora::embedding] Done iter: 14. Dims: 32, entities: 34246, num data points: 7009582.
# [2024-02-07T23:50:45Z INFO  cleora::embedding] Done iter: 15. Dims: 32, entities: 34246, num data points: 7009582.
# [2024-02-07T23:50:45Z INFO  cleora::embedding] Done propagating.
# [2024-02-07T23:50:45Z INFO  cleora::embedding] Start saving embeddings.
# [2024-02-07T23:50:45Z INFO  cleora::embedding] Done saving embeddings.
# [2024-02-07T23:50:45Z INFO  cleora::embedding] Finalizing embeddings calculations!
# [2024-02-07T23:50:45Z INFO  cleora] Finished in 3 sec

# %%
class RatingGenerator:
    def __init__(self):
        self.users_count = None
        self.columns = ["user", "anime"]
        self.rankings = dict()

    def get_artifacts(self):
        p = "results/emb__"
        files = ["labels", "vects_iter"]
        suf = [".out.entities", ".out.npy"]

        return {f: f"{p}{self.columns[0]}__{self.columns[1]}{suf[idx]}"
                for idx, f in enumerate(files)}

    def load_artifacts(self):
        artifacts = self.get_artifacts()
        with open(artifacts['labels'], "r") as entities:
            self.labels = np.array([int(i) for i in json.load(entities)])
        # Load results to numpy
        self.vects_iter = np.load(artifacts['vects_iter'])

    def load_rankings(self, idx: int):
        real_id = np.where(self.labels == idx)[0][0]

        v = self.vects_iter[real_id]
        dist = sklearn.metrics.pairwise.cosine_similarity(v.reshape(1, -1),
                                                          self.vects_iter,
                                                          dense_output=True)
        ranking = (-dist).argsort()[0]

        self.rankings[self.labels[real_id]] = self.labels[ranking[:15]]

    def add_to_custom_ranking(self, custom_ranking, idx: int):
        anime_ranking = self.rankings[idx]

        for anime in anime_ranking:
            if anime in custom_ranking:
                custom_ranking[anime] += 1
            else:
                custom_ranking[anime] = 1

    def predict(self, already_watched):

        self.load_artifacts()
        custom_ranking = dict()

        for idx in tqdm(already_watched):
            if idx not in self.rankings:
                self.load_rankings(idx)

            self.add_to_custom_ranking(custom_ranking, idx)

        return dict(sorted(custom_ranking.items(),
                           reverse=True,
                           key=lambda x: x[1]))

# %%
two_mode_data="dataset/anime-dataset-2023.csv"
anime_df = Data_factory.from_csv(two_mode_data)

# %%
# Ranking

ratingGenerator = RatingGenerator()

def pandas_extract_content(row, label):
    name = row[label].to_string()
    return name.split("    ")[1]

ranking = ratingGenerator.predict([67, 6702, 242])
for label, times in ranking.items():
    filter = anime_df[anime_df.anime_id == label]
    if len(filter) == 0:
        continue

    print(f"{pandas_extract_content(filter, 'Name')}: {times}")
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# Tatsu no Ko Tarou: 2
# Tentai Senshi Sunred: 1
# Eyeshield 21: Jump Festa 2005 Special: 1
# Nitaboh: 1
# Shakugan no Shana Movie: 1
# Hellsing: 1
# Hayate no Gotoku!: 1
# Sentou Yousei Yukikaze: 1
# Yume no Crayon Oukoku: 1
# Di Gi Charat Natsuyasumi Special: 1
# Kojika Monogatari: 1
# Hachimitsu to Clover: 1
# Chiisana Obake: Acchi, Kocchi, Socchi: 1
# Space Adventure Cobra: 1
# Tobira wo Akete (1995): 1
# Yami Shibai: 1
# Arata naru Sekai: World's/Start/Load/End: 1
# Yu☆Gi☆Oh! Zexal Second: Iza! Saishuu Kessen e!! Special: 1
# Wakako-zake: 1
# Oshare Kozou wa Hanamaru: 1
# Kaitou Joker 2nd Season: 1
# One Piece: Kinkyuu Kikaku One Piece Kanzen Kouryakuhou: 1
# Dragon Quest: Dai no Daibouken Tachiagare!! Aban no Shito: 1
# Cheer Danshi!! Recap: 1
# Aku no Hana: 1
# Naruto: Honoo no Chuunin Shiken! Naruto vs. Konohamaru!!: 1
# Shin Strange+ Special: 1
# Tonari no Seki-kun OVA: 1
# Shin Strange+: 1
# More feat. Anderson .Paak: 1
# Zombie-Loan Specials: 1
# Kure-nai: 1
# Oyayubi Hime Monogatari: 1
# Soukou no Strain: 1
# Kuruneko: 1
# Sora wo Miageru Shoujo no Hitomi ni Utsuru Sekai: 1
# Tantei Gakuen Q: 1
# Final Fantasy VII: Last Order: 1
# Final Fantasy VII: Advent Children: 1
# Glass no Kantai: La Legende du Vent de l'Univers: 1
# Transformers: The☆Headmasters: 1
# Ohayou! Spank: 1
# Boku no Chikyuu wo Mamotte: 1
# Konchuu Monogatari Minashigo Hutch (1989): 1

# %%
def extract_year(aired):
    return aired.split(",")[1].split(" ")[1]

def search_str(s, search):
    return search in str(s).lower()

def find_by_name(name):
    name = name.lower()
    mask = anime_df.apply(lambda x: x.map(lambda s: search_str(s, name)))
    return anime_df.loc[mask.any(axis=1)]

find_by_name("blend s").head(50)
# Out:
#        anime_id          Name        English name Other name Score  \
# 938        1033  Sennen Joyuu  Millennium Actress       千年女優  8.25
# 12446     34618       Blend S             BLEND-S     ブレンド・S  7.27
#
#                                                           Genres  \
# 938    Action, Adventure, Award Winning, Drama, Fantasy, Romance
# 12446                                                     Comedy
#
#                                                                                                                                                                                                                                                                                                           Synopsis  \
# 938    At the turn of the millennium, Ginei Studio's dilapidated buildings are set to be demolished. Ex-employee and filmmaker Genya Tachibana decides to honor this occasion with a commemorative documentary about the company's star actress: Chiyoko Fujiwara, the reclusive sweetheart of Shouwa Era cinem...
# 12446  Wishing to be independent, 16-year-old Maika Sakuranomiya is desperate to nail down a part-time job so that she can afford to study abroad. Unfortunately, her applications are constantly rejected due to the menacing look she unintentionally makes whenever she smiles, despite her otherwise cheerf...
#
#         Type Episodes                        Aired  ...       Studios  \
# 938    Movie      1.0                 Sep 14, 2002  ...      Madhouse
# 12446     TV     12.0  Oct 8, 2017 to Dec 24, 2017  ...  A-1 Pictures
#
#              Source       Duration                     Rating    Rank  \
# 938        Original    1 hr 26 min  PG-13 - Teens 13 or older   289.0
# 12446  4-koma manga  23 min per ep  PG-13 - Teens 13 or older  2689.0
#
#       Popularity Favorites Scored By Members  \
# 938         1261      2488   79434.0  176075
# 12446        300      2931  357334.0  636259
#
#                                                      Image URL
# 938    https://cdn.myanimelist.net/images/anime/1648/93626.jpg
# 12446     https://cdn.myanimelist.net/images/anime/6/88286.jpg
#
# [2 rows x 24 columns]

# %%
def df_from_array(array):
    return pd.DataFrame(data=array[1:,1:], index=array[1:,0], columns=array[0,1:])

def read_data(file):
    with open(file, newline='') as csvfile:
        reader = csv.reader(csvfile, delimiter=',')
        return [ np.array([i] + list(row)) for i, row in enumerate(reader, start=-1)]

def get_genre_list(genres: str):
  return list(map(lambda x: x.strip().lower(), genres.split(",")))

def filter_out(word, col):
  return lambda row: not (word.lower() in get_genre_list(row[col]))

def filter_in(word, col):
  return lambda row: (word.lower() in get_genre_list(row[col]))

def create_two_mode_df(data):
    sub_df = data[["anime_id", "English name", "Genres"]]
    result = [['id', 'source', 'target']]
    i=0
    for _, row in sub_df.iterrows():
        for genre in get_genre_list(row['Genres']):
            to_append = [i, row['English name'], genre]
            result.append(to_append)
            i+=1
    return df_from_array(np.array(result))

def create_weighted_matrix(two_mode_df):
    assert(two_mode_df.columns.tolist() == ['source', 'target'])
    source_uniq = two_mode_df['source'].unique()
    source_len = source_uniq.shape[0]
    source_dict = {k: v for v, k in enumerate(source_uniq)}
    array = np.zeros((source_len, source_len), dtype=int)

    for _, source1 in tqdm(two_mode_df.iterrows(), total=len(two_mode_df.index)):
        for _, source2 in two_mode_df.iterrows():
            if source1['target'] == source2['target']:
                array[source_dict[source1['source']], source_dict[source2['source']]] += 1
    return pd.DataFrame(data=array, columns=source_uniq, index=source_uniq)

def create_weighted_matrix2(two_mode_df):
    adj_df = pd.crosstab(two_mode_df.source, two_mode_df.target)
    adj_np = adj_df.to_numpy()
    adj_np2 = adj_np@adj_np.T
    return (adj_np2, adj_df.index)


def create_weighted_df(matrix_df):
    result=[['', 'source', 'target', 'weight']]
    c = 0
    for rowIndex, row in tqdm(matrix_df.iterrows(), total=len(matrix_df.index)): #iterate over rows
        for colIndex, value in row.items():
            weight = matrix_df.at[rowIndex, colIndex]
            if weight > 0:
                to_append = [str(c), rowIndex, colIndex, weight]
                result.append(to_append)
                c += 1
    return df_from_array(np.array(result))

# %%
raw_data = read_data(two_mode_data)
# raw_data = raw_data[:1000]

# %%
all_data = df_from_array(np.array(raw_data))

# %%
all_data.columns
# Out:
# Index(['anime_id', 'Name', 'English name', 'Other name', 'Score', 'Genres',
#        'Synopsis', 'Type', 'Episodes', 'Aired', 'Premiered', 'Status',
#        'Producers', 'Licensors', 'Studios', 'Source', 'Duration', 'Rating',
#        'Rank', 'Popularity', 'Favorites', 'Scored By', 'Members', 'Image URL'],
#       dtype='object')

# %%
all_data = all_data[(all_data['Score'] != "UNKNOWN") & (all_data['Score'] != '')].astype({'Score': 'float'})
# all_data = all_data.drop(columns=['Synopsis', 'Aired', 'Image URL', 'Scored By', 'Members', 'Licensors'])
# all_data = all_data[all_data['Score'] > 7.0]
important_data = all_data.drop(columns=['Synopsis', 'Aired', 'Image URL', 'Scored By', 'Members', 'Licensors'])

# %%
movies = important_data[important_data['Type'] == "Movie"]
TVs = important_data[important_data['Type'] == "TV"]
specials = important_data[important_data['Type'] == "Special"]

specified = important_data

not_hentai = specified[specified.apply(filter_out("Hentai", 'Genres'), axis=1)]
hentai = specified[specified.apply(filter_in("Hentai", 'Genres'), axis=1)]

mappa = not_hentai[not_hentai.apply(filter_in("Mappa", "Studios"), axis=1)]

# %%
# not_hentai.sort_values(['Score'], ascending=False)
print(len(hentai))
print(len(not_hentai))
# Out:
# 1465
# 14227

# %%
data = all_data[["anime_id", "English name", "Genres", "Score"]]
data = data[(data['Score'] != "UNKNOWN") & (data['Score'] != '')].astype({'Score': 'float'})

# %%
data.dtypes

mapped = map(get_genre_list, data["Genres"].to_numpy().flatten().tolist())

uniq = np.unique(list(chain.from_iterable(mapped))).tolist()

print(len(uniq), uniq)
# Out:
# 22 ['action', 'adventure', 'avant garde', 'award winning', 'boys love', 'comedy', 'drama', 'ecchi', 'erotica', 'fantasy', 'girls love', 'gourmet', 'hentai', 'horror', 'mystery', 'romance', 'sci-fi', 'slice of life', 'sports', 'supernatural', 'suspense', 'unknown']

# %%
two_mode_df = create_two_mode_df(data)

two_mode_df
# Out:
#                                                   source         target
# 0                                           Cowboy Bebop         action
# 1                                           Cowboy Bebop  award winning
# 2                                           Cowboy Bebop         sci-fi
# 3                                Cowboy Bebop: The Movie         action
# 4                                Cowboy Bebop: The Movie         sci-fi
# ...                                                  ...            ...
# 30955  One Piece: Recapping Fierce Fights! The Counte...         action
# 30956  One Piece: Recapping Fierce Fights! The Counte...      adventure
# 30957  One Piece: Recapping Fierce Fights! The Counte...         comedy
# 30958  One Piece: Recapping Fierce Fights! The Counte...        fantasy
# 30959                                               Fins        unknown
#
# [30960 rows x 2 columns]

# %%
(weighted_matrix_np, weighted_matrix_index) = create_weighted_matrix2(two_mode_df)

# %%
weighted_matrix_df2 = pd.DataFrame(data=weighted_matrix_np, index=weighted_matrix_index, columns=weighted_matrix_index)

# %%
weighted_matrix_df2
# Out:
# source                                         "Deji" Meets Girl  \
# source
# "Deji" Meets Girl                                              1
# "Ippon" again!                                                 0
# "Parade" de Satie                                              0
# "Star"t                                                        0
# -OutsideR:RequieM-                                             0
# ...                                                          ...
# xxxHOLiC                                                       0
# xxxHOLiC The Movie: A Midsummer Night's Dream                  0
# ∀ Gundam                                                       0
# ∀ Gundam I: Earth Light                                        0
# ∀ Gundam II: Moonlight Butterfly                               0
#
# source                                         "Ippon" again!  \
# source
# "Deji" Meets Girl                                           0
# "Ippon" again!                                              1
# "Parade" de Satie                                           0
# "Star"t                                                     0
# -OutsideR:RequieM-                                          0
# ...                                                       ...
# xxxHOLiC                                                    0
# xxxHOLiC The Movie: A Midsummer Night's Dream               0
# ∀ Gundam                                                    0
# ∀ Gundam I: Earth Light                                     0
# ∀ Gundam II: Moonlight Butterfly                            0
#
# source                                         "Parade" de Satie  "Star"t  \
# source
# "Deji" Meets Girl                                              0        0
# "Ippon" again!                                                 0        0
# "Parade" de Satie                                              1        0
# "Star"t                                                        0        1
# -OutsideR:RequieM-                                             0        1
# ...                                                          ...      ...
# xxxHOLiC                                                       0        0
# xxxHOLiC The Movie: A Midsummer Night's Dream                  0        0
# ∀ Gundam                                                       0        0
# ∀ Gundam I: Earth Light                                        0        0
# ∀ Gundam II: Moonlight Butterfly                               0        0
#
# source                                         -OutsideR:RequieM-  .Koni-chan  \
# source
# "Deji" Meets Girl                                               0           0
# "Ippon" again!                                                  0           0
# "Parade" de Satie                                               0           0
# "Star"t                                                         1           0
# -OutsideR:RequieM-                                              1           0
# ...                                                           ...         ...
# xxxHOLiC                                                        0           1
# xxxHOLiC The Movie: A Midsummer Night's Dream                   0           1
# ∀ Gundam                                                        0           0
# ∀ Gundam I: Earth Light                                         0           0
# ∀ Gundam II: Moonlight Butterfly                                0           0
#
# source                                         .hack//G.U. Trilogy  \
# source
# "Deji" Meets Girl                                                0
# "Ippon" again!                                                   0
# "Parade" de Satie                                                0
# "Star"t                                                          0
# -OutsideR:RequieM-                                               0
# ...                                                            ...
# xxxHOLiC                                                         0
# xxxHOLiC The Movie: A Midsummer Night's Dream                    0
# ∀ Gundam                                                         1
# ∀ Gundam I: Earth Light                                          1
# ∀ Gundam II: Moonlight Butterfly                                 1
#
# source                                         .hack//G.U. Trilogy: Parody Mode  \
# source
# "Deji" Meets Girl                                                             0
# "Ippon" again!                                                                0
# "Parade" de Satie                                                             0
# "Star"t                                                                       0
# -OutsideR:RequieM-                                                            0
# ...                                                                         ...
# xxxHOLiC                                                                      1
# xxxHOLiC The Movie: A Midsummer Night's Dream                                 1
# ∀ Gundam                                                                      1
# ∀ Gundam I: Earth Light                                                       1
# ∀ Gundam II: Moonlight Butterfly                                              1
#
# source                                         .hack//Gift  \
# source
# "Deji" Meets Girl                                        0
# "Ippon" again!                                           0
# "Parade" de Satie                                        0
# "Star"t                                                  0
# -OutsideR:RequieM-                                       0
# ...                                                    ...
# xxxHOLiC                                                 1
# xxxHOLiC The Movie: A Midsummer Night's Dream            1
# ∀ Gundam                                                 0
# ∀ Gundam I: Earth Light                                  0
# ∀ Gundam II: Moonlight Butterfly                         0
#
# source                                         .hack//Legend of The Twilight  \
# source
# "Deji" Meets Girl                                                          0
# "Ippon" again!                                                             0
# "Parade" de Satie                                                          0
# "Star"t                                                                    0
# -OutsideR:RequieM-                                                         0
# ...                                                                      ...
# xxxHOLiC                                                                   1
# xxxHOLiC The Movie: A Midsummer Night's Dream                              1
# ∀ Gundam                                                                   1
# ∀ Gundam I: Earth Light                                                    0
# ∀ Gundam II: Moonlight Butterfly                                           0
#
# source                                         ...  selector spread WIXOSS  \
# source                                         ...
# "Deji" Meets Girl                              ...                       0
# "Ippon" again!                                 ...                       0
# "Parade" de Satie                              ...                       0
# "Star"t                                        ...                       1
# -OutsideR:RequieM-                             ...                       1
# ...                                            ...                     ...
# xxxHOLiC                                       ...                       0
# xxxHOLiC The Movie: A Midsummer Night's Dream  ...                       0
# ∀ Gundam                                       ...                       0
# ∀ Gundam I: Earth Light                        ...                       0
# ∀ Gundam II: Moonlight Butterfly               ...                       0
#
# source                                         sound / phantasma / mirror  \
# source
# "Deji" Meets Girl                                                       1
# "Ippon" again!                                                          0
# "Parade" de Satie                                                       0
# "Star"t                                                                 0
# -OutsideR:RequieM-                                                      0
# ...                                                                   ...
# xxxHOLiC                                                                0
# xxxHOLiC The Movie: A Midsummer Night's Dream                           0
# ∀ Gundam                                                                0
# ∀ Gundam I: Earth Light                                                 0
# ∀ Gundam II: Moonlight Butterfly                                        0
#
# source                                         teeter  the FLY BanD!  \
# source
# "Deji" Meets Girl                                   0              0
# "Ippon" again!                                      0              0
# "Parade" de Satie                                   0              0
# "Star"t                                             1              1
# -OutsideR:RequieM-                                  1              1
# ...                                               ...            ...
# xxxHOLiC                                            0              0
# xxxHOLiC The Movie: A Midsummer Night's Dream       0              0
# ∀ Gundam                                            0              0
# ∀ Gundam I: Earth Light                             0              0
# ∀ Gundam II: Moonlight Butterfly                    0              0
#
# source                                         tsuritama  xxxHOLiC  \
# source
# "Deji" Meets Girl                                      1         0
# "Ippon" again!                                         0         0
# "Parade" de Satie                                      0         0
# "Star"t                                                0         0
# -OutsideR:RequieM-                                     0         0
# ...                                                  ...       ...
# xxxHOLiC                                               1         4
# xxxHOLiC The Movie: A Midsummer Night's Dream          1         4
# ∀ Gundam                                               1         1
# ∀ Gundam I: Earth Light                                1         1
# ∀ Gundam II: Moonlight Butterfly                       1         1
#
# source                                         xxxHOLiC The Movie: A Midsummer Night's Dream  \
# source
# "Deji" Meets Girl                                                                          0
# "Ippon" again!                                                                             0
# "Parade" de Satie                                                                          0
# "Star"t                                                                                    0
# -OutsideR:RequieM-                                                                         0
# ...                                                                                      ...
# xxxHOLiC                                                                                   4
# xxxHOLiC The Movie: A Midsummer Night's Dream                                              4
# ∀ Gundam                                                                                   1
# ∀ Gundam I: Earth Light                                                                    1
# ∀ Gundam II: Moonlight Butterfly                                                           1
#
# source                                         ∀ Gundam  \
# source
# "Deji" Meets Girl                                     0
# "Ippon" again!                                        0
# "Parade" de Satie                                     0
# "Star"t                                               0
# -OutsideR:RequieM-                                    0
# ...                                                 ...
# xxxHOLiC                                              1
# xxxHOLiC The Movie: A Midsummer Night's Dream         1
# ∀ Gundam                                              6
# ∀ Gundam I: Earth Light                               3
# ∀ Gundam II: Moonlight Butterfly                      3
#
# source                                         ∀ Gundam I: Earth Light  \
# source
# "Deji" Meets Girl                                                    0
# "Ippon" again!                                                       0
# "Parade" de Satie                                                    0
# "Star"t                                                              0
# -OutsideR:RequieM-                                                   0
# ...                                                                ...
# xxxHOLiC                                                             1
# xxxHOLiC The Movie: A Midsummer Night's Dream                        1
# ∀ Gundam                                                             3
# ∀ Gundam I: Earth Light                                              3
# ∀ Gundam II: Moonlight Butterfly                                     3
#
# source                                         ∀ Gundam II: Moonlight Butterfly
# source
# "Deji" Meets Girl                                                             0
# "Ippon" again!                                                                0
# "Parade" de Satie                                                             0
# "Star"t                                                                       0
# -OutsideR:RequieM-                                                            0
# ...                                                                         ...
# xxxHOLiC                                                                      1
# xxxHOLiC The Movie: A Midsummer Night's Dream                                 1
# ∀ Gundam                                                                      3
# ∀ Gundam I: Earth Light                                                       3
# ∀ Gundam II: Moonlight Butterfly                                              3
#
# [7916 rows x 7916 columns]

# %%
weighted_matrix_df_pickle_file = "weighted_matrix_df.df"
if os.path.exists(weighted_matrix_df_pickle_file):
    weighted_matrix_df = pd.read_pickle(weighted_matrix_df_pickle_file)
else:
    weighted_matrix_df = weighted_matrix_df2
    weighted_matrix_df.to_pickle(weighted_matrix_df_pickle_file)

# %%
weighted_matrix_df
# Out:
# source                                         "Deji" Meets Girl  \
# source
# "Deji" Meets Girl                                              1
# "Ippon" again!                                                 0
# "Parade" de Satie                                              0
# "Star"t                                                        0
# -OutsideR:RequieM-                                             0
# ...                                                          ...
# xxxHOLiC                                                       0
# xxxHOLiC The Movie: A Midsummer Night's Dream                  0
# ∀ Gundam                                                       0
# ∀ Gundam I: Earth Light                                        0
# ∀ Gundam II: Moonlight Butterfly                               0
#
# source                                         "Ippon" again!  \
# source
# "Deji" Meets Girl                                           0
# "Ippon" again!                                              1
# "Parade" de Satie                                           0
# "Star"t                                                     0
# -OutsideR:RequieM-                                          0
# ...                                                       ...
# xxxHOLiC                                                    0
# xxxHOLiC The Movie: A Midsummer Night's Dream               0
# ∀ Gundam                                                    0
# ∀ Gundam I: Earth Light                                     0
# ∀ Gundam II: Moonlight Butterfly                            0
#
# source                                         "Parade" de Satie  "Star"t  \
# source
# "Deji" Meets Girl                                              0        0
# "Ippon" again!                                                 0        0
# "Parade" de Satie                                              1        0
# "Star"t                                                        0        1
# -OutsideR:RequieM-                                             0        1
# ...                                                          ...      ...
# xxxHOLiC                                                       0        0
# xxxHOLiC The Movie: A Midsummer Night's Dream                  0        0
# ∀ Gundam                                                       0        0
# ∀ Gundam I: Earth Light                                        0        0
# ∀ Gundam II: Moonlight Butterfly                               0        0
#
# source                                         -OutsideR:RequieM-  .Koni-chan  \
# source
# "Deji" Meets Girl                                               0           0
# "Ippon" again!                                                  0           0
# "Parade" de Satie                                               0           0
# "Star"t                                                         1           0
# -OutsideR:RequieM-                                              1           0
# ...                                                           ...         ...
# xxxHOLiC                                                        0           1
# xxxHOLiC The Movie: A Midsummer Night's Dream                   0           1
# ∀ Gundam                                                        0           0
# ∀ Gundam I: Earth Light                                         0           0
# ∀ Gundam II: Moonlight Butterfly                                0           0
#
# source                                         .hack//G.U. Trilogy  \
# source
# "Deji" Meets Girl                                                0
# "Ippon" again!                                                   0
# "Parade" de Satie                                                0
# "Star"t                                                          0
# -OutsideR:RequieM-                                               0
# ...                                                            ...
# xxxHOLiC                                                         0
# xxxHOLiC The Movie: A Midsummer Night's Dream                    0
# ∀ Gundam                                                         1
# ∀ Gundam I: Earth Light                                          1
# ∀ Gundam II: Moonlight Butterfly                                 1
#
# source                                         .hack//G.U. Trilogy: Parody Mode  \
# source
# "Deji" Meets Girl                                                             0
# "Ippon" again!                                                                0
# "Parade" de Satie                                                             0
# "Star"t                                                                       0
# -OutsideR:RequieM-                                                            0
# ...                                                                         ...
# xxxHOLiC                                                                      1
# xxxHOLiC The Movie: A Midsummer Night's Dream                                 1
# ∀ Gundam                                                                      1
# ∀ Gundam I: Earth Light                                                       1
# ∀ Gundam II: Moonlight Butterfly                                              1
#
# source                                         .hack//Gift  \
# source
# "Deji" Meets Girl                                        0
# "Ippon" again!                                           0
# "Parade" de Satie                                        0
# "Star"t                                                  0
# -OutsideR:RequieM-                                       0
# ...                                                    ...
# xxxHOLiC                                                 1
# xxxHOLiC The Movie: A Midsummer Night's Dream            1
# ∀ Gundam                                                 0
# ∀ Gundam I: Earth Light                                  0
# ∀ Gundam II: Moonlight Butterfly                         0
#
# source                                         .hack//Legend of The Twilight  \
# source
# "Deji" Meets Girl                                                          0
# "Ippon" again!                                                             0
# "Parade" de Satie                                                          0
# "Star"t                                                                    0
# -OutsideR:RequieM-                                                         0
# ...                                                                      ...
# xxxHOLiC                                                                   1
# xxxHOLiC The Movie: A Midsummer Night's Dream                              1
# ∀ Gundam                                                                   1
# ∀ Gundam I: Earth Light                                                    0
# ∀ Gundam II: Moonlight Butterfly                                           0
#
# source                                         ...  selector spread WIXOSS  \
# source                                         ...
# "Deji" Meets Girl                              ...                       0
# "Ippon" again!                                 ...                       0
# "Parade" de Satie                              ...                       0
# "Star"t                                        ...                       1
# -OutsideR:RequieM-                             ...                       1
# ...                                            ...                     ...
# xxxHOLiC                                       ...                       0
# xxxHOLiC The Movie: A Midsummer Night's Dream  ...                       0
# ∀ Gundam                                       ...                       0
# ∀ Gundam I: Earth Light                        ...                       0
# ∀ Gundam II: Moonlight Butterfly               ...                       0
#
# source                                         sound / phantasma / mirror  \
# source
# "Deji" Meets Girl                                                       1
# "Ippon" again!                                                          0
# "Parade" de Satie                                                       0
# "Star"t                                                                 0
# -OutsideR:RequieM-                                                      0
# ...                                                                   ...
# xxxHOLiC                                                                0
# xxxHOLiC The Movie: A Midsummer Night's Dream                           0
# ∀ Gundam                                                                0
# ∀ Gundam I: Earth Light                                                 0
# ∀ Gundam II: Moonlight Butterfly                                        0
#
# source                                         teeter  the FLY BanD!  \
# source
# "Deji" Meets Girl                                   0              0
# "Ippon" again!                                      0              0
# "Parade" de Satie                                   0              0
# "Star"t                                             1              1
# -OutsideR:RequieM-                                  1              1
# ...                                               ...            ...
# xxxHOLiC                                            0              0
# xxxHOLiC The Movie: A Midsummer Night's Dream       0              0
# ∀ Gundam                                            0              0
# ∀ Gundam I: Earth Light                             0              0
# ∀ Gundam II: Moonlight Butterfly                    0              0
#
# source                                         tsuritama  xxxHOLiC  \
# source
# "Deji" Meets Girl                                      1         0
# "Ippon" again!                                         0         0
# "Parade" de Satie                                      0         0
# "Star"t                                                0         0
# -OutsideR:RequieM-                                     0         0
# ...                                                  ...       ...
# xxxHOLiC                                               1         4
# xxxHOLiC The Movie: A Midsummer Night's Dream          1         4
# ∀ Gundam                                               1         1
# ∀ Gundam I: Earth Light                                1         1
# ∀ Gundam II: Moonlight Butterfly                       1         1
#
# source                                         xxxHOLiC The Movie: A Midsummer Night's Dream  \
# source
# "Deji" Meets Girl                                                                          0
# "Ippon" again!                                                                             0
# "Parade" de Satie                                                                          0
# "Star"t                                                                                    0
# -OutsideR:RequieM-                                                                         0
# ...                                                                                      ...
# xxxHOLiC                                                                                   4
# xxxHOLiC The Movie: A Midsummer Night's Dream                                              4
# ∀ Gundam                                                                                   1
# ∀ Gundam I: Earth Light                                                                    1
# ∀ Gundam II: Moonlight Butterfly                                                           1
#
# source                                         ∀ Gundam  \
# source
# "Deji" Meets Girl                                     0
# "Ippon" again!                                        0
# "Parade" de Satie                                     0
# "Star"t                                               0
# -OutsideR:RequieM-                                    0
# ...                                                 ...
# xxxHOLiC                                              1
# xxxHOLiC The Movie: A Midsummer Night's Dream         1
# ∀ Gundam                                              6
# ∀ Gundam I: Earth Light                               3
# ∀ Gundam II: Moonlight Butterfly                      3
#
# source                                         ∀ Gundam I: Earth Light  \
# source
# "Deji" Meets Girl                                                    0
# "Ippon" again!                                                       0
# "Parade" de Satie                                                    0
# "Star"t                                                              0
# -OutsideR:RequieM-                                                   0
# ...                                                                ...
# xxxHOLiC                                                             1
# xxxHOLiC The Movie: A Midsummer Night's Dream                        1
# ∀ Gundam                                                             3
# ∀ Gundam I: Earth Light                                              3
# ∀ Gundam II: Moonlight Butterfly                                     3
#
# source                                         ∀ Gundam II: Moonlight Butterfly
# source
# "Deji" Meets Girl                                                             0
# "Ippon" again!                                                                0
# "Parade" de Satie                                                             0
# "Star"t                                                                       0
# -OutsideR:RequieM-                                                            0
# ...                                                                         ...
# xxxHOLiC                                                                      1
# xxxHOLiC The Movie: A Midsummer Night's Dream                                 1
# ∀ Gundam                                                                      3
# ∀ Gundam I: Earth Light                                                       3
# ∀ Gundam II: Moonlight Butterfly                                              3
#
# [7916 rows x 7916 columns]

# %%
# weighted_df_pickle_file = "weighted_df.df"
# if os.path.exists(weighted_df_pickle_file):
#     weighted_df = pd.read_pickle(weighted_df_pickle_file)
# else:
#     weighted_df = create_weighted_df(weighted_matrix_df)
#     weighted_df.to_pickle(weighted_df_pickle_file)

# %%
# weighted_df

# %%
# weighted_df.columns

# %%
# for i in [3, 2, 1]:
# G = nx.from_pandas_edgelist(
#         weighted_df, source='source',
#         target='target', edge_attr='weight')

plt.figure(figsize=(35,35))

G = nx.from_numpy_array(weighted_matrix_np)
graph_pos = nx.spring_layout(G)
nx.draw_networkx_nodes(G, graph_pos, node_size=10, node_color='blue', alpha=0.3)
nx.draw_networkx_edges(G, graph_pos)
nx.draw_networkx_labels(G, graph_pos, font_size=8, font_family='sans-serif')

# plt.show()

# nx.draw(G)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 11
#       9 graph_pos = nx.spring_layout(G)
#      10 nx.draw_networkx_nodes(G, graph_pos, node_size=10, node_color='blue', alpha=0.3)
# ---> 11 nx.draw_networkx_edges(G, graph_pos)
#      12 nx.draw_networkx_labels(G, graph_pos, font_size=8, font_family='sans-serif')
#      14 # plt.show()
#      15
#      16 # nx.draw(G)
#
# File ~/.pyenv/versions/3.11.6/envs/ml-anime/lib/python3.11/site-packages/networkx/drawing/nx_pylab.py:902, in draw_networkx_edges(G, pos, edgelist, width, edge_color, style, alpha, arrowstyle, arrowsize, edge_cmap, edge_vmin, edge_vmax, ax, arrows, label, node_size, nodelist, node_shape, connectionstyle, min_source_margin, min_target_margin)
#     900 edge_viz_obj = _draw_networkx_edges_line_collection()
#     901 # Make sure selfloop edges are also drawn
# --> 902 selfloops_to_draw = [loop for loop in nx.selfloop_edges(G) if loop in edgelist]
#     903 if selfloops_to_draw:
#     904     fancy_edges_indices = [
#     905         edgelist_tuple.index(loop) for loop in selfloops_to_draw
#     906     ]
#
# File ~/.pyenv/versions/3.11.6/envs/ml-anime/lib/python3.11/site-packages/networkx/drawing/nx_pylab.py:902, in <listcomp>(.0)
#     900 edge_viz_obj = _draw_networkx_edges_line_collection()
#     901 # Make sure selfloop edges are also drawn
# --> 902 selfloops_to_draw = [loop for loop in nx.selfloop_edges(G) if loop in edgelist]
#     903 if selfloops_to_draw:
#     904     fancy_edges_indices = [
#     905         edgelist_tuple.index(loop) for loop in selfloops_to_draw
#     906     ]
#
# KeyboardInterrupt:

# %%
plt.savefig("plot.svg", dpi=1200)

# %%
net = Network(notebook=True)
net.from_nx(G)
net.show("example.html")
