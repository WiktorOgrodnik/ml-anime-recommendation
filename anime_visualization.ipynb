# %%
# Standard IPython notebook imports
# %matplotlib inline

import os
import csv
import math
import ast
import json
import shutil

import pyarrow
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import sklearn.metrics

import subprocess

from tqdm.notebook import tqdm
from itertools import chain
from typing import Optional

pd.options.display.max_colwidth = 300

# %%
USERS_CSV="dataset/user-filtered.csv"
ANIME_CSV="dataset/anime-dataset-2023.csv"

# %%
def load_pd(filepath, line_count: int | None):
    return pd.read_csv(filepath, sep=',', nrows=line_count)

# %%
# %%time
LINES = 10000000

users_df = load_pd(USERS_CSV, LINES)
animes_df = load_pd(ANIME_CSV, None)

# is user data loaded?
len(users_df)
len(animes_df)
# Out:
# CPU times: user 1.36 s, sys: 290 ms, total: 1.65 s
# Wall time: 1.73 s
# 24905

# %%
class AnimeRecomendation:
    def __init__(self, users_df=pd.DataFrame(), animes_df=pd.DataFrame()):
        self.users_df = users_df
        self.animes_df = animes_df
        self.users_count = None
        self.columns = ['user', 'anime']
        self.grouped_columns = ['user_id', 'anime_id']
        self.tsv_filename = None
        self.popularity_threshold = 6000

    def change_data(self, users_df, animes_df):
        self.users_df = users_df
        self.animes_df = animes_df

        return self.number_of_users()

    def from_csv(self, file: str):
        self.tsv_filename = file
        self.grouped_df = pd.read_csv(file,
                                      sep="\t",
                                      header=None,
                                      names=self.grouped_columns)

    def choose(self, nousers: int):
        if nousers <= self.number_of_users():
            self.users_df = self.users_df.sample(n=nousers)

    def number_of_users(self):
        if self.users_count is None:
            self.users_count = self.users_df.max()['user_id']
        return self.users_count

    def fit(self, rating_threshold=6):

        def adj_mult(rating: int) -> int:
            match rating:
                case 6 | 7: return 1
                case 8 | 9: return 2
                case 10: return 3
                case _: return 0

        def agg_fun(anime: str, rating: int) -> str:
            return " ".join([str(anime)] * adj_mult(rating))


        self.animes_df = self.animes_df[(self.animes_df['Popularity'] <= self.popularity_threshold) &
                                        (self.animes_df['Popularity'] > 0)]

        self.users_df = self.users_df[self.users_df['rating'] >= rating_threshold]
        self.users_df = self.users_df[self.users_df['anime_id'].isin(self.animes_df['anime_id'])]
        self.animes_df = self.animes_df[self.animes_df['anime_id'].isin(self.users_df['anime_id'])]

        self.users_df = (self.users_df
            .assign(id_rating=lambda x: list(zip(x['anime_id'], x['rating'])))
            .groupby('user_id')['id_rating']
            .agg(lambda animes: " ".join([agg_fun(anime, rating) for (anime, rating) in animes]))
            .reset_index()
            .rename(columns={'id_rating': 'anime_id'}))

        self.animes_df = (self.animes_df
            .assign(genre=lambda x: x['Genres'].apply(lambda x: list(map(str.strip, x.split(",")))))
            .filter(items=['anime_id', 'genre'])
            .explode('genre')
            .groupby('genre')
            .agg(lambda genres: " ".join([str(i) for i in genres]))
            .reset_index()
            .rename(columns={'genre': 'user_id'}))

        self.grouped_df = self.users_df

        return self.number_of_users()

    def save_to_tsv(self, tsv_filename: str):
        self.tsv_filename = tsv_filename
        self.grouped_df.to_csv(self.tsv_filename,
                               index=False,
                               sep='\t',
                               columns=self.grouped_columns,
                               mode='w',
                               header=False)
        self.animes_df.to_csv("animes.tsv",
                               index=False,
                               sep='\t',
                               columns=self.grouped_columns,
                               mode='w',
                               header=False)

    def cleora_train(self, cleora_exe="./cleora-exe", dimensions=32, iter=16):
        if self.tsv_filename is None:
            raise RuntimeError("TSV filename not yet created")
        if not os.access(cleora_exe, os.X_OK) and shutil.which(cleora_exe) is None:
            raise RuntimeError(f"cleora executable not found: {cleora_exe}")

        command = [cleora_exe,
                   "--type", "tsv",
                   f"--columns=transient::{self.columns[0]} complex::{self.columns[1]}",
                   "--dimension", str(dimensions),
                   "--number-of-iterations", str(iter),
                   "--prepend-field-name", "0",
                   "-f", "numpy",
                   "-o", "results",
                   "-e", "1",
                   self.tsv_filename]
        subprocess.run(command, check=True)

        command = [cleora_exe,
                   "--type", "tsv",
                   f"--columns=transient::genre complex::anime",
                   "--dimension", "8",
                   "--number-of-iterations", str(iter),
                   "--prepend-field-name", "0",
                   "-f", "numpy",
                   "-o", "results",
                   "-e", "1",
                   "animes.tsv"]
        subprocess.run(command, check=True)

# %%
model = AnimeRecomendation(users_df=users_df, animes_df=animes_df)

# %%
# %%time
RATING_THRESHOLD = 6

model.fit(rating_threshold=RATING_THRESHOLD)
# Out:
# CPU times: user 6.96 s, sys: 1.26 s, total: 8.22 s
# Wall time: 8.32 s
# 32600

# %%
x = model.users_df['anime_id'].apply(lambda x: x.split(' ')).explode().unique()
x.sort()
y = model.animes_df['anime_id'].apply(lambda x: x.split(' ')).explode().unique()
y.sort()
np.all(x == y)
# Out:
# True

# %%
# %%time
# constructing the tsv data

tsv_file_name = "data.tsv"
model.save_to_tsv(tsv_file_name)
# Out:
# CPU times: user 753 ms, sys: 67.2 ms, total: 820 ms
# Wall time: 848 ms

# %%
# %%time

CLEORA_EXE = './cleora-exe'
DIMENSIONS = 64
ITER = 64

# You shouldnt be running it every time!

# Commented it out for safety reasons xd
model.cleora_train(cleora_exe=CLEORA_EXE, dimensions=DIMENSIONS, iter=ITER)
# Out:
# [2024-02-11T17:11:00Z INFO  cleora] Reading args...
# [src/main.rs:222] &config = Configuration {
#     produce_entity_occurrence_count: true,
#     embeddings_dimension: 64,
#     max_number_of_iteration: 64,
#     seed: None,
#     prepend_field: false,
#     log_every_n: 10000,
#     in_memory_embedding_calculation: true,
#     input: [
#         "data.tsv",
#     ],
#     file_type: Tsv,
#     output_dir: Some(
#         "results",
#     ),
#     output_format: Numpy,
#     relation_name: "emb",
#     columns: [
#         Column {
#             name: "user",
#             transient: true,
#             complex: false,
#             reflexive: false,
#             ignored: false,
#         },
#         Column {
#             name: "anime",
#             transient: false,
#             complex: true,
#             reflexive: false,
#             ignored: false,
#         },
#     ],
# }
# [2024-02-11T17:11:00Z INFO  cleora] Starting calculation...
# [src/pipeline.rs:25] &sparse_matrices = [
#     SparseMatrix {
#         col_a_id: 0,
#         col_a_name: "user",
#         col_b_id: 1,
#         col_b_name: "anime",
#         edge_count: 0,
#         hash_2_id: {},
#         id_2_hash: [],
#         row_sum: [],
#         pair_index: {},
#         entries: [],
#     },
# ]
# [2024-02-11T17:11:00Z INFO  cleora::pipeline] Number of lines processed: 10000
# [2024-02-11T17:11:01Z INFO  cleora::pipeline] Number of lines processed: 20000
# [2024-02-11T17:11:02Z INFO  cleora::sparse_matrix] Number of entities: 34120
# [2024-02-11T17:11:02Z INFO  cleora::sparse_matrix] Number of edges: 8454163
# [2024-02-11T17:11:02Z INFO  cleora::sparse_matrix] Number of entries: 9707338
# [2024-02-11T17:11:02Z INFO  cleora::sparse_matrix] Total memory usage by the struct ~ 361 MB
# [2024-02-11T17:11:02Z INFO  cleora] Finished Sparse Matrices calculation in 2 sec
# [2024-02-11T17:11:02Z INFO  cleora::embedding] Start initialization. Dims: 64, entities: 34120.
# [2024-02-11T17:11:02Z INFO  cleora::embedding] Done initializing. Dims: 64, entities: 34120.
# [2024-02-11T17:11:02Z INFO  cleora::embedding] Start propagating. Number of iterations: 64.
# [2024-02-11T17:11:03Z INFO  cleora::embedding] Done iter: 0. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:03Z INFO  cleora::embedding] Done iter: 1. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:04Z INFO  cleora::embedding] Done iter: 2. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:04Z INFO  cleora::embedding] Done iter: 3. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:05Z INFO  cleora::embedding] Done iter: 4. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:05Z INFO  cleora::embedding] Done iter: 5. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:05Z INFO  cleora::embedding] Done iter: 6. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:06Z INFO  cleora::embedding] Done iter: 7. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:06Z INFO  cleora::embedding] Done iter: 8. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:07Z INFO  cleora::embedding] Done iter: 9. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:07Z INFO  cleora::embedding] Done iter: 10. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:08Z INFO  cleora::embedding] Done iter: 11. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:08Z INFO  cleora::embedding] Done iter: 12. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:09Z INFO  cleora::embedding] Done iter: 13. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:09Z INFO  cleora::embedding] Done iter: 14. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:10Z INFO  cleora::embedding] Done iter: 15. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:10Z INFO  cleora::embedding] Done iter: 16. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:10Z INFO  cleora::embedding] Done iter: 17. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:11Z INFO  cleora::embedding] Done iter: 18. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:11Z INFO  cleora::embedding] Done iter: 19. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:12Z INFO  cleora::embedding] Done iter: 20. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:12Z INFO  cleora::embedding] Done iter: 21. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:13Z INFO  cleora::embedding] Done iter: 22. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:13Z INFO  cleora::embedding] Done iter: 23. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:13Z INFO  cleora::embedding] Done iter: 24. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:14Z INFO  cleora::embedding] Done iter: 25. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:14Z INFO  cleora::embedding] Done iter: 26. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:14Z INFO  cleora::embedding] Done iter: 27. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:15Z INFO  cleora::embedding] Done iter: 28. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:15Z INFO  cleora::embedding] Done iter: 29. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:16Z INFO  cleora::embedding] Done iter: 30. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:16Z INFO  cleora::embedding] Done iter: 31. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:17Z INFO  cleora::embedding] Done iter: 32. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:17Z INFO  cleora::embedding] Done iter: 33. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:18Z INFO  cleora::embedding] Done iter: 34. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:18Z INFO  cleora::embedding] Done iter: 35. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:19Z INFO  cleora::embedding] Done iter: 36. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:19Z INFO  cleora::embedding] Done iter: 37. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:19Z INFO  cleora::embedding] Done iter: 38. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:20Z INFO  cleora::embedding] Done iter: 39. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:20Z INFO  cleora::embedding] Done iter: 40. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:21Z INFO  cleora::embedding] Done iter: 41. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:21Z INFO  cleora::embedding] Done iter: 42. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:22Z INFO  cleora::embedding] Done iter: 43. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:22Z INFO  cleora::embedding] Done iter: 44. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:22Z INFO  cleora::embedding] Done iter: 45. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:23Z INFO  cleora::embedding] Done iter: 46. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:23Z INFO  cleora::embedding] Done iter: 47. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:24Z INFO  cleora::embedding] Done iter: 48. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:24Z INFO  cleora::embedding] Done iter: 49. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:24Z INFO  cleora::embedding] Done iter: 50. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:25Z INFO  cleora::embedding] Done iter: 51. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:25Z INFO  cleora::embedding] Done iter: 52. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:26Z INFO  cleora::embedding] Done iter: 53. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:26Z INFO  cleora::embedding] Done iter: 54. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:27Z INFO  cleora::embedding] Done iter: 55. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:27Z INFO  cleora::embedding] Done iter: 56. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:28Z INFO  cleora::embedding] Done iter: 57. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:28Z INFO  cleora::embedding] Done iter: 58. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:28Z INFO  cleora::embedding] Done iter: 59. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:29Z INFO  cleora::embedding] Done iter: 60. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:29Z INFO  cleora::embedding] Done iter: 61. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 62. Dims: 64, entities: 34120, num data points: 9707338.
# CPU times: user 179 ms, sys: 19.5 ms, total: 198 ms
# Wall time: 30.7 s
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 63. Dims: 64, entities: 34120, num data points: 9707338.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done propagating.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Start saving embeddings.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done saving embeddings.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Finalizing embeddings calculations!
# [2024-02-11T17:11:30Z INFO  cleora] Finished in 30 sec
# [2024-02-11T17:11:30Z INFO  cleora] Reading args...
# [src/main.rs:222] &config = Configuration {
#     produce_entity_occurrence_count: true,
#     embeddings_dimension: 8,
#     max_number_of_iteration: 64,
#     seed: None,
#     prepend_field: false,
#     log_every_n: 10000,
#     in_memory_embedding_calculation: true,
#     input: [
#         "animes.tsv",
#     ],
#     file_type: Tsv,
#     output_dir: Some(
#         "results",
#     ),
#     output_format: Numpy,
#     relation_name: "emb",
#     columns: [
#         Column {
#             name: "genre",
#             transient: true,
#             complex: false,
#             reflexive: false,
#             ignored: false,
#         },
#         Column {
#             name: "anime",
#             transient: false,
#             complex: true,
#             reflexive: false,
#             ignored: false,
#         },
#     ],
# }
# [2024-02-11T17:11:30Z INFO  cleora] Starting calculation...
# [src/pipeline.rs:25] &sparse_matrices = [
#     SparseMatrix {
#         col_a_id: 0,
#         col_a_name: "genre",
#         col_b_id: 1,
#         col_b_name: "anime",
#         edge_count: 0,
#         hash_2_id: {},
#         id_2_hash: [],
#         row_sum: [],
#         pair_index: {},
#         entries: [],
#     },
# ]
# [2024-02-11T17:11:30Z INFO  cleora::sparse_matrix] Number of entities: 5308
# [2024-02-11T17:11:30Z INFO  cleora::sparse_matrix] Number of edges: 13069
# [2024-02-11T17:11:30Z INFO  cleora::sparse_matrix] Number of entries: 26138
# [2024-02-11T17:11:30Z INFO  cleora::sparse_matrix] Total memory usage by the struct ~ 0 MB
# [2024-02-11T17:11:30Z INFO  cleora] Finished Sparse Matrices calculation in 0 sec
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Start initialization. Dims: 8, entities: 5308.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done initializing. Dims: 8, entities: 5308.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Start propagating. Number of iterations: 64.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 0. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 1. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 2. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 3. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 4. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 5. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 6. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 7. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 8. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 9. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 10. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 11. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 12. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 13. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 14. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 15. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 16. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 17. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 18. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 19. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 20. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 21. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 22. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 23. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 24. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 25. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 26. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 27. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 28. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 29. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 30. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 31. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 32. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 33. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 34. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 35. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 36. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 37. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 38. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 39. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 40. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 41. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 42. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 43. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 44. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 45. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 46. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 47. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 48. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 49. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 50. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 51. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 52. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 53. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 54. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 55. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 56. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 57. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 58. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 59. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 60. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 61. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 62. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done iter: 63. Dims: 8, entities: 5308, num data points: 26138.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done propagating.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Start saving embeddings.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Done saving embeddings.
# [2024-02-11T17:11:30Z INFO  cleora::embedding] Finalizing embeddings calculations!
# [2024-02-11T17:11:30Z INFO  cleora] Finished in 0 sec

# %%
class RatingGenerator:
    def __init__(self):
        self.users_count = None
        self.columns = ["user", "anime"]
        self.rankings = dict()
        self.anime_by_genre = self.get_anime_by_genre()

    def get_anime_by_genre(self):
        anime_df = pd.read_csv(ANIME_CSV)
        return (anime_df
            .assign(genre=lambda x: x['Genres'].apply(lambda x: list(map(str.strip, x.split(",")))))
            .filter(items=['anime_id', 'genre'])
            .explode('genre')
            .groupby('genre')
            .agg(list))

    def get_artifacts(self):
        p = "results/emb__"
        files = ["labels", "vects_iter"]
        suf = [".out.entities", ".out.npy"]

        return {'users': {f: f"{p}{self.columns[0]}__{self.columns[1]}{suf[idx]}"
                            for idx, f in enumerate(files)},
                'genres': {f: f"{p}genre__anime{suf[idx]}"
                            for idx, f in enumerate(files)}}

    def get_dist_to_genre(self, genre: str):
        dists = []
        for anime_id in self.labels:
            dists.append(genre in self.anime_df.loc[anime_id]['Genres'])

        return np.array(dists).astype(float)

    def load_artifacts(self):
        artifacts = self.get_artifacts()
        with open(artifacts['users']['labels'], "r") as entities:
            self.labels = np.array([int(i) for i in json.load(entities)])

        with open(artifacts['genres']['labels'], "r") as entities:
            self.glabels = glabels = np.array([int(i) for i in json.load(entities)])

        self.vects_iter = np.load(artifacts['users']['vects_iter'])
        self.gvects_iter = np.load(artifacts['genres']['vects_iter'])

        self.vects_iter = self.vects_iter[self.labels.argsort()]
        self.labels.sort()

        self.gvects_iter = self.gvects_iter[glabels.argsort()]
        glabels.sort()

        # assert np.all(self.labels == glabels)


    def load_rankings(self, idx: int, preffered_genres: list[str]):
        real_id = np.where(self.labels == idx)[0][0]

        uv = self.vects_iter[real_id]
        udist = sklearn.metrics.pairwise.cosine_similarity(uv.reshape(1, -1),
                                                          self.vects_iter,
                                                          dense_output=True)

        gv = self.gvects_iter[real_id]
        gdist = sklearn.metrics.pairwise.cosine_similarity(gv.reshape(1, -1),
                                                           self.gvects_iter,
                                                           dense_output=True)

        if len(preffered_genres) == 0:
            dists_to_preffered_genres = udist[0]
        else:
            dists_to_preffered_genres = np.mean(
                [self.get_dist_to_genre(genre) for genre in preffered_genres],
                axis=0)

        dist = 0.7 * udist[0] + 0.2 * gdist[0] + 0.1 * dists_to_preffered_genres

        ranking = (-dist).argsort()

        self.rankings[idx] = self.labels[ranking[:15]]

    def add_to_custom_ranking(self, custom_ranking, idx: int):
        anime_ranking = self.rankings[idx]

        for anime in anime_ranking:
            if anime in custom_ranking:
                custom_ranking[anime] += 1
            else:
                custom_ranking[anime] = 1

    def predict(self, already_watched, preferred_genres: list[str]):

        self.load_artifacts()
        custom_ranking = dict()

        for idx in tqdm(already_watched):
            if idx not in self.rankings:
                self.load_rankings(idx, preferred_genres)

            self.add_to_custom_ranking(custom_ranking, idx)

        return dict(sorted(custom_ranking.items(),
                           reverse=True,
                           key=lambda x: x[1]))

# %%
rg = RatingGenerator()
rg.load_artifacts()
rg.glabels, rg.labels
# Out:
# (array([    1,     5,     6, ..., 47591, 47616, 48456]),
#  array([    1,     5,     6, ..., 47591, 47616, 48456]))

# %%
rg.anime_by_genre.loc['Action']['anime_id']
# Out:
# [1,
#  5,
#  6,
#  7,
#  18,
#  20,
#  21,
#  23,
#  25,
#  26,
#  27,
#  29,
#  30,
#  33,
#  43,
#  44,
#  45,
#  47,
#  51,
#  54,
#  55,
#  60,
#  61,
#  64,
#  65,
#  67,
#  68,
#  69,
#  71,
#  72,
#  73,
#  75,
#  76,
#  77,
#  80,
#  90,
#  91,
#  93,
#  94,
#  95,
#  97,
#  98,
#  110,
#  112,
#  113,
#  121,
#  127,
#  128,
#  129,
#  130,
#  131,
#  132,
#  134,
#  136,
#  137,
#  138,
#  139,
#  142,
#  149,
#  150,
#  151,
#  152,
#  153,
#  154,
#  155,
#  156,
#  161,
#  164,
#  165,
#  168,
#  169,
#  174,
#  175,
#  177,
#  180,
#  181,
#  184,
#  185,
#  186,
#  187,
#  194,
#  198,
#  202,
#  204,
#  205,
#  206,
#  207,
#  208,
#  209,
#  210,
#  212,
#  218,
#  219,
#  221,
#  222,
#  223,
#  225,
#  226,
#  227,
#  230,
#  231,
#  238,
#  249,
#  266,
#  267,
#  269,
#  270,
#  271,
#  272,
#  274,
#  278,
#  282,
#  284,
#  285,
#  288,
#  290,
#  296,
#  297,
#  300,
#  301,
#  305,
#  315,
#  317,
#  320,
#  321,
#  340,
#  347,
#  355,
#  356,
#  359,
#  366,
#  370,
#  374,
#  375,
#  377,
#  378,
#  384,
#  389,
#  392,
#  395,
#  396,
#  397,
#  398,
#  399,
#  400,
#  404,
#  408,
#  411,
#  416,
#  417,
#  426,
#  432,
#  434,
#  438,
#  442,
#  446,
#  447,
#  449,
#  450,
#  451,
#  452,
#  459,
#  460,
#  461,
#  462,
#  463,
#  464,
#  465,
#  466,
#  467,
#  473,
#  478,
#  479,
#  481,
#  482,
#  483,
#  486,
#  492,
#  493,
#  498,
#  502,
#  504,
#  515,
#  527,
#  528,
#  537,
#  539,
#  540,
#  541,
#  543,
#  544,
#  548,
#  550,
#  552,
#  554,
#  560,
#  561,
#  565,
#  566,
#  567,
#  571,
#  573,
#  582,
#  589,
#  594,
#  598,
#  599,
#  602,
#  603,
#  619,
#  621,
#  624,
#  635,
#  636,
#  650,
#  690,
#  693,
#  709,
#  712,
#  732,
#  738,
#  751,
#  758,
#  760,
#  762,
#  763,
#  767,
#  769,
#  777,
#  791,
#  801,
#  807,
#  808,
#  813,
#  821,
#  822,
#  833,
#  834,
#  839,
#  842,
#  854,
#  856,
#  857,
#  860,
#  876,
#  878,
#  882,
#  883,
#  884,
#  887,
#  888,
#  889,
#  890,
#  891,
#  892,
#  893,
#  894,
#  895,
#  896,
#  897,
#  898,
#  899,
#  900,
#  901,
#  902,
#  903,
#  904,
#  905,
#  906,
#  913,
#  916,
#  917,
#  918,
#  924,
#  925,
#  926,
#  929,
#  935,
#  936,
#  937,
#  938,
#  944,
#  949,
#  953,
#  956,
#  958,
#  961,
#  967,
#  968,
#  969,
#  970,
#  971,
#  974,
#  977,
#  978,
#  979,
#  987,
#  988,
#  991,
#  992,
#  998,
#  999,
#  1000,
#  1002,
#  1006,
#  1009,
#  1010,
#  1011,
#  1017,
#  1019,
#  1020,
#  1022,
#  1024,
#  1027,
#  1033,
#  1034,
#  1037,
#  1043,
#  1051,
#  1052,
#  1055,
#  1057,
#  1059,
#  1062,
#  1067,
#  1069,
#  1072,
#  1074,
#  1076,
#  1079,
#  1080,
#  1081,
#  1086,
#  1088,
#  1089,
#  1090,
#  1091,
#  1092,
#  1094,
#  1101,
#  1102,
#  1107,
#  1111,
#  1112,
#  1118,
#  1122,
#  1130,
#  1132,
#  1133,
#  1135,
#  1136,
#  1145,
#  1147,
#  1149,
#  1150,
#  1153,
#  1156,
#  1157,
#  1160,
#  1165,
#  1167,
#  1176,
#  1178,
#  1179,
#  1180,
#  1181,
#  1182,
#  1189,
#  1191,
#  1194,
#  1195,
#  1202,
#  1211,
#  1212,
#  1221,
#  1224,
#  1225,
#  1226,
#  1228,
#  1231,
#  1232,
#  1233,
#  1236,
#  1237,
#  1238,
#  1244,
#  1245,
#  1246,
#  1248,
#  1249,
#  1252,
#  1253,
#  1254,
#  1257,
#  1259,
#  1261,
#  1262,
#  1268,
#  1269,
#  1270,
#  1276,
#  1285,
#  1286,
#  1287,
#  1292,
#  1293,
#  1295,
#  1296,
#  1297,
#  1298,
#  1303,
#  1313,
#  1314,
#  1331,
#  1336,
#  1338,
#  1341,
#  1342,
#  1343,
#  1344,
#  1345,
#  1346,
#  1348,
#  1349,
#  1350,
#  1351,
#  1352,
#  1355,
#  1356,
#  1357,
#  1362,
#  1372,
#  1378,
#  1381,
#  1383,
#  1384,
#  1397,
#  1398,
#  1399,
#  1400,
#  1410,
#  1412,
#  1413,
#  1414,
#  1415,
#  1416,
#  1417,
#  1418,
#  1419,
#  1420,
#  1421,
#  1422,
#  1423,
#  1424,
#  1425,
#  1426,
#  1427,
#  1428,
#  1429,
#  1430,
#  1431,
#  1432,
#  1433,
#  1434,
#  1435,
#  1436,
#  1437,
#  1438,
#  1439,
#  1442,
#  1443,
#  1451,
#  1454,
#  1455,
#  1456,
#  1457,
#  1458,
#  1459,
#  1460,
#  1465,
#  1468,
#  1469,
#  1470,
#  1471,
#  1472,
#  1473,
#  1474,
#  1475,
#  1476,
#  1477,
#  1481,
#  1482,
#  1484,
#  1488,
#  1490,
#  1492,
#  1493,
#  1498,
#  1517,
#  1519,
#  1525,
#  1526,
#  1529,
#  1534,
#  1536,
#  1537,
#  1538,
#  1541,
#  1542,
#  1544,
#  1553,
#  1557,
#  1559,
#  1560,
#  1564,
#  1565,
#  1568,
#  1573,
#  1575,
#  1576,
#  1577,
#  1582,
#  1583,
#  1590,
#  1596,
#  1599,
#  1603,
#  1604,
#  1606,
#  1609,
#  1618,
#  1620,
#  1621,
#  1622,
#  1623,
#  1626,
#  1628,
#  1629,
#  1641,
#  1643,
#  1645,
#  1647,
#  1650,
#  1651,
#  1652,
#  1657,
#  1658,
#  1660,
#  1661,
#  1664,
#  1665,
#  1667,
#  1668,
#  1669,
#  1670,
#  1671,
#  1675,
#  1676,
#  1678,
#  1681,
#  1682,
#  1685,
#  1686,
#  1691,
#  1693,
#  1694,
#  1696,
#  1703,
#  1704,
#  1706,
#  1707,
#  1708,
#  1709,
#  1710,
#  1713,
#  1719,
#  1726,
#  1731,
#  1733,
#  1735,
#  1736,
#  1737,
#  1738,
#  1740,
#  1743,
#  1745,
#  1746,
#  1747,
#  1751,
#  1759,
#  1760,
#  1761,
#  1762,
#  1763,
#  1766,
#  1768,
#  1769,
#  1771,
#  1773,
#  1774,
#  1775,
#  1777,
#  1789,
#  1790,
#  1792,
#  1793,
#  1794,
#  1795,
#  1796,
#  1799,
#  1800,
#  1802,
#  1803,
#  1805,
#  1806,
#  1807,
#  1811,
#  1815,
#  1816,
#  1818,
#  1820,
#  1822,
#  1823,
#  1827,
#  1828,
#  1830,
#  1831,
#  1832,
#  1833,
#  1835,
#  1837,
#  1840,
#  1844,
#  1845,
#  1848,
#  1849,
#  1850,
#  1853,
#  1854,
#  1860,
#  1862,
#  1865,
#  1866,
#  1873,
#  1879,
#  1880,
#  1898,
#  1899,
#  1900,
#  1901,
#  1903,
#  1911,
#  1913,
#  1915,
#  1920,
#  1921,
#  1922,
#  1923,
#  1924,
#  1925,
#  1927,
#  1928,
#  1929,
#  1932,
#  1933,
#  1935,
#  1938,
#  1944,
#  1947,
#  1952,
#  1954,
#  1956,
#  1959,
#  1962,
#  1964,
#  1972,
#  1977,
#  1978,
#  1980,
#  1992,
#  2001,
#  2002,
#  2003,
#  2009,
#  2010,
#  2011,
#  2013,
#  2014,
#  2019,
#  2022,
#  2023,
#  2025,
#  2026,
#  2031,
#  2032,
#  2042,
#  2043,
#  2048,
#  2049,
#  2050,
#  2051,
#  2056,
#  2057,
#  2058,
#  2060,
#  2061,
#  2062,
#  2063,
#  2064,
#  2065,
#  2066,
#  2067,
#  2068,
#  2070,
#  2080,
#  2083,
#  2084,
#  2087,
#  2089,
#  2090,
#  2094,
#  2097,
#  2107,
#  2108,
#  2109,
#  2110,
#  2111,
#  2113,
#  2114,
#  2123,
#  2124,
#  2125,
#  2126,
#  2127,
#  2128,
#  2130,
#  2138,
#  2143,
#  2144,
#  2154,
#  2156,
#  2158,
#  2161,
#  2163,
#  2169,
#  2170,
#  2174,
#  2176,
#  2178,
#  2185,
#  2196,
#  2200,
#  2201,
#  2202,
#  2203,
#  2205,
#  2209,
#  2212,
#  2214,
#  2216,
#  2234,
#  2243,
#  2248,
#  2249,
#  2251,
#  2252,
#  2253,
#  2254,
#  2255,
#  2256,
#  2257,
#  2258,
#  2262,
#  2269,
#  2273,
#  2283,
#  2285,
#  2291,
#  2292,
#  2293,
#  2294,
#  2298,
#  2299,
#  2300,
#  2301,
#  2302,
#  2307,
#  2312,
#  2315,
#  2318,
#  2319,
#  2321,
#  2324,
#  2331,
#  2332,
#  2335,
#  2341,
#  2346,
#  2359,
#  2361,
#  2362,
#  2364,
#  2382,
#  2383,
#  2389,
#  2390,
#  2404,
#  2408,
#  2418,
#  2422,
#  2423,
#  2448,
#  2449,
#  2451,
#  2452,
#  2453,
#  2461,
#  2462,
#  2463,
#  2470,
#  2472,
#  2473,
#  2474,
#  2475,
#  2479,
#  2480,
#  2482,
#  2483,
#  2484,
#  2510,
#  2511,
#  2516,
#  2521,
#  2524,
#  2527,
#  2560,
#  2561,
#  2581,
#  2582,
#  2583,
#  2584,
#  2589,
#  2592,
#  2593,
#  2598,
#  2599,
#  2600,
#  2601,
#  2603,
#  2606,
#  2607,
#  2608,
#  2619,
#  2620,
#  2622,
#  2682,
#  2683,
#  2684,
#  2685,
#  2688,
#  2689,
#  2690,
#  2692,
#  2694,
#  2695,
#  2696,
#  2697,
#  2698,
#  2699,
#  2700,
#  2704,
#  2709,
#  2713,
#  2717,
#  2719,
#  2722,
#  2723,
#  2724,
#  2726,
#  2727,
#  2731,
#  2734,
#  2735,
#  2737,
#  2740,
#  2741,
#  2745,
#  2746,
#  2747,
#  2754,
#  2757,
#  2759,
#  2762,
#  2765,
#  2768,
#  2769,
#  2770,
#  2772,
#  2775,
#  2776,
#  2777,
#  2778,
#  2780,
#  2782,
#  2785,
#  2786,
#  2787,
#  2791,
#  2792,
#  2795,
#  2797,
#  2803,
#  2808,
#  2818,
#  2819,
#  2820,
#  2837,
#  2839,
#  2847,
#  2851,
#  2881,
#  2884,
#  2889,
#  2901,
#  2903,
#  2904,
#  2906,
#  2920,
#  2933,
#  2941,
#  2946,
#  2951,
#  2952,
#  2961,
#  2969,
#  2978,
#  2980,
#  2987,
#  2988,
#  3000,
#  3008,
#  3014,
#  3015,
#  3016,
#  3019,
#  3021,
#  3022,
#  3024,
#  3025,
#  3027,
#  3028,
#  3035,
#  3036,
#  3044,
#  3059,
#  3060,
#  3064,
#  3065,
#  3067,
#  3069,
#  3070,
#  3071,
#  3072,
#  3080,
#  3086,
#  3087,
#  3098,
#  3099,
#  3100,
#  3101,
#  3104,
#  3114,
#  3115,
#  3116,
#  3127,
#  3135,
#  3147,
#  3152,
#  3153,
#  3154,
#  3155,
#  3157,
#  3166,
#  3175,
#  3178,
#  3183,
#  3192,
#  3193,
#  3213,
#  3214,
#  3222,
#  3223,
#  3227,
#  3231,
#  3232,
#  3234,
#  3235,
#  3248,
#  3251,
#  3254,
#  ...]

# %%
# Ranking

ratingGenerator = RatingGenerator()

def pandas_extract_content(row, label):
    name = row[label].to_string()
    return name.split("    ")[1]

ranking = ratingGenerator.predict([67, 6702, 242], [])
for label, times in ranking.items():
    filter = animes_df[animes_df.anime_id == label]
    if len(filter) == 0:
        continue

    print(f"{pandas_extract_content(filter, 'Name')}: {times}")
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# Okusama wa Joshikousei (TV): 1
# Koisuru Tenshi Angelique: Kagayaki no Ashita: 1
# Tong Ling Fei: 1
# Mahoutsukai no Yome: 1
# Kodomo no Omocha (TV): 1
# Akagami no Shirayuki-hime 2nd Season: 1
# Romeo x Juliet: 1
# Shinkyoku Soukai Polyphonica: 1
# Sister Princess: 1
# Bakuman. 2nd Season: 1
# Basilisk: Kouga Ninpou Chou: 1
# Nagi no Asu kara: 1
# I My Me! Strawberry Eggs: 1
# RDG: Red Data Girl: 1
# Otome wa Boku ni Koishiteru: 1
# Naruto: 1
# King's Raid: Ishi wo Tsugumono-tachi: 1
# Nanatsu no Taizai: Kamigami no Gekirin: 1
# Boruto: Jump Festa 2016 Special: 1
# Pokemon Generations: 1
# Ta ga Tame no Alchemist: 1
# Divine Gate: 1
# Gate: Jieitai Kanochi nite, Kaku Tatakaeri Part 2: 1
# Pokemon Best Wishes!: 1
# Toaru Kagaku no Railgun: Misaka-san wa Ima Chuumoku no Mato desu kara: 1
# Gunjou no Magmell: 1
# Isekai Cheat Magician: 1
# Macross Dynamite 7: 1
# Street Fighter II Movie: 1
# Toaru Majutsu no Index II: 1
# Nodame Cantabile OVA: 1
# Yuuki Yuuna wa Yuusha de Aru: Washio Sumi no Shou 1 - Tomodachi: 1
# Acchi Kocchi: 1
# Yuuki Yuuna wa Yuusha de Aru: Washio Sumi no Shou 2 - Tamashii: 1
# Tamayura: Hitotose: 1
# Tamayura: Sotsugyou Shashin Part 1 - Kizashi: 1
# Tsuyokiss: 1
# Tamayura: More Aggressive: 1
# Tamayura: Sotsugyou Shashin Part 4 - Ashita: 1
# Tamayura: 1
# Binbou Shimai Monogatari: 1
# Watashi no Ashinaga Ojisan: 1
# Gokusen: 1
# Beck: 1
# Miyori no Mori: 1

# %%
def extract_year(aired):
    return aired.split(",")[1].split(" ")[1]

def search_str(s, search):
    return search in str(s).lower()

def find_in_rows(name):
    name = name.lower()
    mask = anime_df.apply(lambda x: x.map(lambda s: search_str(s, name)))
    return anime_df.loc[mask.any(axis=1)]

def find_by_name(name):
    return anime_df[anime_df['Name'].str.lower().str.contains(name.lower(), na=False)]
    
find_by_name("Shingeki no Kyojin").head(10).anime_id
